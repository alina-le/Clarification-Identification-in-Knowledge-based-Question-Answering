# %% [markdown]
# # Open Prompt Classifier
# Based on this tutorial: https://github.com/thunlp/OpenPrompt/blob/main/tutorial/0_basic.py and tutorial from Natalia Skachkova and Tatiana Anikina

# %%
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
cd /content/drive/MyDrive/thesis/prompting/open_prompt_classifier
# Out:
# /content/drive/MyDrive/thesis/prompting/open_prompt_classifier

# %%
# !pip install openprompt
# !pip install torch
# Out:
# Collecting openprompt
#   Downloading openprompt-1.0.1-py3-none-any.whl (146 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.4/146.4 kB 3.3 MB/s eta 0:00:00
# Collecting transformers>=4.10.0 (from openprompt)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 60.4 MB/s eta 0:00:00
# Collecting sentencepiece==0.1.96 (from openprompt)
#   Downloading sentencepiece-0.1.96-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 70.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.2 in /usr/local/lib/python3.10/dist-packages (from openprompt) (4.66.1)
# Collecting tensorboardX (from openprompt)
#   Downloading tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 12.3 MB/s eta 0:00:00
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from openprompt) (3.8.1)
# Collecting yacs (from openprompt)
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting dill (from openprompt)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.9 MB/s eta 0:00:00
# Collecting datasets (from openprompt)
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 50.5 MB/s eta 0:00:00
# Collecting rouge==1.0.0 (from openprompt)
#   Downloading rouge-1.0.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from openprompt) (9.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from openprompt) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge==1.0.0->openprompt) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (3.12.4)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.10.0->openprompt)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 30.0 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.10.0->openprompt)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.3 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.10.0->openprompt)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 82.7 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (1.5.3)
# Collecting xxhash (from datasets->openprompt)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 23.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->openprompt)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (3.8.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->openprompt) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->openprompt) (1.3.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX->openprompt) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.10.0->openprompt) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (2023.7.22)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.10.0->openprompt)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 30.8 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openprompt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openprompt) (2023.3.post1)
# Installing collected packages: sentencepiece, safetensors, yacs, xxhash, tensorboardX, rouge, dill, multiprocess, huggingface-hub, tokenizers, transformers, datasets, openprompt
# Successfully installed datasets-2.14.5 dill-0.3.7 huggingface-hub-0.16.4 multiprocess-0.70.15 openprompt-1.0.1 rouge-1.0.0 safetensors-0.3.3 sentencepiece-0.1.96 tensorboardX-2.6.2.2 tokenizers-0.14.0 transformers-4.34.0 xxhash-3.4.1 yacs-0.1.8
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
# !pip install import-ipynb
import import_ipynb
# Out:
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.10/dist-packages (from import-ipynb) (7.34.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from import-ipynb) (5.9.2)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (67.7.2)
# Collecting jedi>=0.16 (from IPython->import-ipynb)
#   Downloading jedi-0.19.1-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.9 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (2.18.1)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (4.19.1)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from nbformat->import-ipynb) (5.3.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.10.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.8)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core->nbformat->import-ipynb) (3.11.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.19.1

# %%
from openprompt import PromptForClassification
from openprompt.plms import load_plm

from openprompt.prompts import ManualTemplate, ManualVerbalizer, SoftTemplate
from openprompt import PromptDataLoader

from claqua_prompt_dataset import CLAQUAPromptProcessor

import torch

import re
from datetime import datetime
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation_utils.py:24: FutureWarning: Importing `GenerationMixin` from `src/transformers/generation_utils.py` is deprecated and will be removed in Transformers v5. Import as `from transformers import GenerationMixin` instead.
#   warnings.warn(
# importing Jupyter notebook from claqua_prompt_dataset.ipynb
# Requirement already satisfied: openprompt in /usr/local/lib/python3.10/dist-packages (1.0.1)
# Requirement already satisfied: transformers>=4.10.0 in /usr/local/lib/python3.10/dist-packages (from openprompt) (4.34.0)
# Requirement already satisfied: sentencepiece==0.1.96 in /usr/local/lib/python3.10/dist-packages (from openprompt) (0.1.96)
# Requirement already satisfied: tqdm>=4.62.2 in /usr/local/lib/python3.10/dist-packages (from openprompt) (4.66.1)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.10/dist-packages (from openprompt) (2.6.2.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from openprompt) (3.8.1)
# Requirement already satisfied: yacs in /usr/local/lib/python3.10/dist-packages (from openprompt) (0.1.8)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from openprompt) (0.3.7)
# Requirement already satisfied: datasets in /usr/local/lib/python3.10/dist-packages (from openprompt) (2.14.5)
# Requirement already satisfied: rouge==1.0.0 in /usr/local/lib/python3.10/dist-packages (from openprompt) (1.0.0)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from openprompt) (9.0.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from openprompt) (1.11.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from rouge==1.0.0->openprompt) (1.16.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (3.12.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (0.16.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (2.31.0)
# Requirement already satisfied: tokenizers<0.15,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (0.14.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.10.0->openprompt) (0.3.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (3.4.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (0.70.15)
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->openprompt) (3.8.5)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->openprompt) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->openprompt) (1.3.2)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorboardX->openprompt) (3.20.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->openprompt) (1.3.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.10.0->openprompt) (4.5.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.10.0->openprompt) (2023.7.22)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openprompt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->openprompt) (2023.3.post1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (17.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
use_cuda = True
device = "cuda"

# %%
# !cp /content/drive/MyDrive/thesis/prompting/open_prompt_classifier/read_claqua_corpus.py /content
# !cp /content/drive/MyDrive/thesis/prompting/open_prompt_classifier/preprocess_claqua_single_turn.py /content
# !cp /content/drive/MyDrive/thesis/prompting/open_prompt_classifier/preprocess_claqua_multi_turn.py /content

# %%
from read_claqua_corpus import read_train_dev_test

# %%
# Setting up the hyperparameters
num_epochs = 3
template_filename = "claqua_soft_template_5.txt"
corpus_split = "multi-turn"
init_from_vocab = True
freeze_lm = False
num_soft_tokens = 50 #[10, 50, 100]
batch_size = 8 #[8, 16]
learning_rate = 5e-5
model = "bert"
model_name_or_path = "bert-base-cased"
store_dir = "saved_models/"
do_train = True

plm, tokenizer, model_config, WrapperClass = load_plm(model, model_name_or_path)
# Preparing the template and the verbalizer
with open(template_filename, 'r') as f:
  for line in f:
    print(line)
mytemplate = SoftTemplate(model=plm, tokenizer=tokenizer, num_tokens=num_soft_tokens, initialize_from_vocab=init_from_vocab).from_file(template_filename, choice=0)#
myverbalizer = ManualVerbalizer(tokenizer, num_classes=2, label_words=[["no"], ["yes"]])
pmodel_name = "claqua_"+corpus_split+"_"+model+"_"+"softtokens"+str(num_soft_tokens)+"_lr"+str(learning_rate)+"_batch"+str(batch_size)+"_epochs"+str(num_epochs)+"_freeze"+str(freeze_lm)+"__"+template_filename
# Out:
# Some weights of the model checkpoint at bert-base-cased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# {"placeholder":"text_a"} Does this context question to a knowledge-based question answering system need a clarification request? {"mask"}

# %%
pmodel_name
# Out:
# 'claqua_multi-turn_bert_softtokens50_lr5e-05_batch8_epochs3_freezeFalse__claqua_soft_template_6.txt'

# %% [markdown]
# ## Reload dataset

# %%
# Load train, dev and test corpus
data_path = "claqua_data"
num_max_toks = 300
TURN_SEP_TOK = ' [TURN_SEP] '
CONTEXT_SEP_TOK = ' [CONTEXT_SEP] '
ENTITY_SEP_TOK = ' [ENTITY_SEP] '
train_corpus, dev_corpus, test_corpus = read_train_dev_test(data_path=data_path, corpus_split=corpus_split, tokenizer=tokenizer, num_max_toks=num_max_toks, turn_sep_tok=TURN_SEP_TOK, context_sep_tok=CONTEXT_SEP_TOK, entity_sep_tok=ENTITY_SEP_TOK)
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1829 > 512). Running this sequence through the model will result in indexing errors

# %%
dataset = {}
dataset['train'] = CLAQUAPromptProcessor(train_corpus.df['label']).get_train_examples(train_corpus.df['full_text_for_encoding'])
dataset['validation'] = CLAQUAPromptProcessor(dev_corpus.df['label']).get_dev_examples(dev_corpus.df['full_text_for_encoding'])
dataset['test'] = CLAQUAPromptProcessor(test_corpus.df['label']).get_test_examples(test_corpus.df['full_text_for_encoding'])
# Out:
# 20462
# 973
# 828

# %%
dataset['train'][1]
# Out:
# {
#   "guid": "1",
#   "label": 1,
#   "meta": {},
#   "text_a": "CONTEXT: Is there a sequel to bazil broketail  [TURN_SEP]  A Sword for a Dragon  [TURN_SEP]  How about the style of this creative work? ENTITY 1: Bazil Broketail Bazil Broketail ( 1992 ) is a fantasy novel written by Christopher Rowley. The book is the first in the Dragons of the Argonath series that follows the adventures of a human boy, Relkin, and his dragon, Bazil Broketail as they fight in the Argonath Legion \u2019 s 109th Mar ENTITY 2: A Sword for a Dragon A Sword for a Dragon is a fantasy novel written by Christopher Rowley. The book is the second in the Dragons of the Argonath series that follows the adventures of a human boy, Relkin, and his dragon, Bazil Broketail as they fight in the Argonath Legion \u2019 s 109th Marneri Dragons. As they continue their service to the Legion, Bazil acquires a new sword that is infused with the spirit of Ecator, an ancient black cat from the city of Tummuz Orgmeen. The 109th Marneri Dragons are dispatched down River Oon to the ancient land of Ourdh where an insurgency is being fueled by the Masters of Padmasa. Once in Ourdh the Legions are besieged in the city by a Mesomaster whom the Legions must overcome to survive",
#   "text_b": "",
#   "tgt_text": "yes"
# }

# %% [markdown]
# ## Train

# %%
# Preparing the training data
#train_dataloader = PromptDataLoader(dataset=dataset["train"][:64], template=mytemplate, tokenizer=tokenizer,
train_dataloader = PromptDataLoader(dataset=dataset["train"], template=mytemplate, tokenizer=tokenizer,
    tokenizer_wrapper_class=WrapperClass, max_seq_length=num_max_toks, decoder_max_length=5,
    batch_size=batch_size,shuffle=True, teacher_forcing=False, predict_eos_token=False,
    truncate_method="head")
# Initializing the prompt model
prompt_model = PromptForClassification(plm=plm, template=mytemplate, verbalizer=myverbalizer, freeze_plm=freeze_lm)
if use_cuda:
    prompt_model = prompt_model.cuda()
# Setting up the loss function and the optimizer
loss_func = torch.nn.CrossEntropyLoss()
no_decay = ['bias', 'LayerNorm.weight']
# A good practice is to set no decay to biase and LayerNorm parameters
optimizer_grouped_parameters = [
    {'params': [p for n, p in prompt_model.named_parameters() if not any(nd in n for nd in no_decay)], 'weight_decay': 0.01},
    {'params': [p for n, p in prompt_model.named_parameters() if any(nd in n for nd in no_decay)], 'weight_decay': 0.0}
]
optimizer = torch.optim.AdamW(optimizer_grouped_parameters, lr=learning_rate)
# Preparing the validation data
#validation_dataloader = PromptDataLoader(dataset=dataset["validation"][:16], template=mytemplate, tokenizer=tokenizer,
validation_dataloader = PromptDataLoader(dataset=dataset["validation"], template=mytemplate, tokenizer=tokenizer,
    tokenizer_wrapper_class=WrapperClass, max_seq_length=num_max_toks, decoder_max_length=5,
    batch_size=batch_size,shuffle=False, teacher_forcing=False, predict_eos_token=False,
    truncate_method="head")
# Out:
# tokenizing: 20462it [01:15, 269.93it/s]
# tokenizing: 973it [00:03, 253.00it/s]

# %%
# Training
now = datetime.now()
print(now)
dev_loss_min = None
if do_train:
    for epoch in range(num_epochs):
        total_loss = 0
        for step, inputs in enumerate(train_dataloader):
            if use_cuda:
                inputs = inputs.cuda()
            logits = prompt_model(inputs)
            labels = inputs['label']
            loss = loss_func(logits, labels)
            loss.backward()
            total_loss += loss.item()
            optimizer.step()
            optimizer.zero_grad()
        # datetime object containing current date and time
        now = datetime.now()
        print("Time {}, Epoch {}, average loss: {}".format(now, epoch, total_loss/(step+1)), flush=True)
        # Evaluation on the development set
        with torch.no_grad():
            cur_loss = 0
            for step, inputs in enumerate(validation_dataloader):
                if use_cuda:
                    inputs = inputs.cuda()
                logits = prompt_model(inputs)
                labels = inputs['label']
                loss = loss_func(logits, labels)
                cur_loss += loss.item()
            cur_loss = cur_loss/(step+1)
            if dev_loss_min is None or cur_loss<dev_loss_min:
                dev_loss_min = cur_loss
                torch.save(prompt_model.state_dict(), store_dir+pmodel_name+".pt")
# Out:
# 2023-10-06 09:19:32.169923
# Time 2023-10-06 09:27:14.748851, Epoch 0, average loss: 0.1012928966973411
# Time 2023-10-06 09:35:05.332903, Epoch 1, average loss: 0.031634247311427444
# Time 2023-10-06 09:42:54.901493, Epoch 2, average loss: 0.020425708075144784

# %%
# Evaluation on the test set
test_dataloader = PromptDataLoader(dataset=dataset["test"], template=mytemplate, tokenizer=tokenizer,
    tokenizer_wrapper_class=WrapperClass, max_seq_length=num_max_toks, decoder_max_length=3,
    batch_size=batch_size,shuffle=False, teacher_forcing=False, predict_eos_token=False,
    truncate_method="head")

prompt_model.load_state_dict(torch.load(store_dir+pmodel_name+".pt"))
#torch.save(prompt_model.template.soft_embeds.data, 'soft_tensors.pt')
print("Evaluating model:", pmodel_name)

alltexts = []
alltexts = [instance.text_a for instance in dataset["test"]]
allpreds = []
alllabels = []
for step, inputs in enumerate(test_dataloader):
    if use_cuda:
        inputs = inputs.cuda()
    logits = prompt_model(inputs)
    labels = inputs['label']
    alllabels.extend(labels.cpu().tolist())
    allpreds.extend(torch.argmax(logits, dim=-1).cpu().tolist())
acc = sum([int(i==j) for i,j in zip(allpreds, alllabels)])/len(allpreds)
print("Accuracy:", acc)
# Out:
# tokenizing: 828it [00:03, 272.11it/s]
# Evaluating model: claqua_multi-turn_bert_softtokens50_lr5e-05_batch8_epochs3_freezeFalse__claqua_soft_template_5.txt
# Accuracy: 0.9347826086956522

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=alllabels, y_pred=allpreds,digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9803    0.8964    0.9365       444
#            1     0.8910    0.9792    0.9330       384
#
#     accuracy                         0.9348       828
#    macro avg     0.9356    0.9378    0.9347       828
# weighted avg     0.9389    0.9348    0.9349       828

# %% [markdown]
# ### Print incorrectly classified corpus items

# %%
all_labels = ["no", "yes"]
id2label = dict()
for i, label in enumerate(all_labels):
    id2label[i] = label

scores = dict()
for label in all_labels:
    scores[label] = {"tp":0, "fp":0, "fn":0}
match = 0
for i in range(len(allpreds)):
    predicted_label = id2label[allpreds[i]]
    gold_label = id2label[alllabels[i]]
    if predicted_label==gold_label:
        match+=1
        scores[predicted_label]["tp"]+=1
    else:
        print("Predicted:", predicted_label)
        print("Gold:", gold_label)
        print("Text:", alltexts[i], "\n")
        scores[predicted_label]["fp"]+=1
        scores[gold_label]["fn"]+=1
# Out:
# Predicted: no
# Gold: yes
# Text: CONTEXT: Where is administrative capital for ferreñafe  [TURN_SEP]  Ferreñafe  [TURN_SEP]  In which time zone? ENTITY 1: Ferreñafe  Ferreñafe District is one of six districts of the province Ferreñafe in Peru. ENTITY 2: Ferreñafe  Ferreñafe is a town in Northern Peru, capital of the province Ferreñafe in the region Lambayeque.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does kia optima 2014 correspond?  [TURN_SEP]  2018 hyundai sonata hybrid  [TURN_SEP]  What was the engine used? ENTITY 1: Kia optima 2014  The 2014 Kia Optima Hybrid adds aerodynamic improvements including restyled front and rear fascias. Additional vents are added to the Optima Hybrid’s front bumper to increase airflow and reduce drag. New 16- and 17-inch wheel designs reduce weight and drag while enhancing the design. The Optima Hybrid features a unique grille design, front LED lighting exclusive to the hybrid model, new Hybrid fender badges and an optional white leather package. The Optima Hybrid features a 47 horsepower electric traction motor, a strong Hybrid Starter Generator and a 47 kW lithium polymer battery. Combined gas-electric power output is 199 horsepower and 235 lb-ft of torque. ENTITY 2: 2018 hyundai sonata hybrid
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the sibling of maria luiga freschet  [TURN_SEP]  Filomena freschet  [TURN_SEP]  Mention the name of the parent. ENTITY 1: Maria Luiga FRESCHET ENTITY 2: Filomena freschet
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: What is name of capital of st. joseph  [TURN_SEP]  south bend  [TURN_SEP]  State the time zone ENTITY 1: St. Joseph St. Joseph County is a county located in the U. S. state of Indiana. Census 2010 put the population at 266, 931. Formed in 1830, it was named for the St. Joseph River which flows through it toward Lake Michigan. The county seat is South Bend. St. Joseph County ENTITY 2: south bend The city of South Bend is the county seat of St. Joseph County, Indiana, United States, on the St. Joseph River near its southernmost bend, from which it derives its name. As of the 2010 census, the city had a total of 101, 168 residents, its Metropolitan Statistical Area had a population of 318, 586 and Combined Statistical Area of 721, 296. It is the fourth - largest city in Indiana, serving as the economic and cultural hub of Northern Indiana. The University of Notre Dame is located just to the north in unincorporated Notre Dame, Indiana. The area was originally settled in the early 19th century by fur traders, and established as a city in 1865. The St. Joseph River shaped South Bend's economy through the mid - 20th century. River access assisted heavy industrial development such as that of the Studebaker Corporation, the Oliver Chilled Plow Company, and other large corporations. The population of South Bend
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who is the parent of rhode schindler truter  [TURN_SEP]  Petrus johannes schindeler truter  [TURN_SEP]  Who is the sibling? ENTITY 1: Rhode Schindler Truter ENTITY 2: Petrus johannes schindeler truter
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the automative class related to bmw i3 2015?  [TURN_SEP]  Toyota prius_v 2015  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Bmw i3 2015 ENTITY 2: Toyota prius_v 2015
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: What is prequel to the monster of florence: a true story  [TURN_SEP]  Blasphemy  [TURN_SEP]  Name its character ENTITY 1: The Monster of Florence : a True Story The Monster of Florence by Mario Spezi In the tradition of John Berendt's Midnight in the Garden of Good and Evil and Erik Larson's The Devil in the White City, Douglas Preston weaves a captivating account of crime and punishment in the lush hills of Florence, Italy. Douglas Preston fulfilled a lifelong dream when he moved with his family to a villa in Florence. Upon meeting celebrated journalist Mario Spezi, Preston was stunned to learn that the olive grove next to his home had been the scene of a horrific double murder committed by one of the most infamous figures in Italian history. A serial killer who ritually murdered fourteen young lovers, he has never been caught. He is known as the Monster of Florence. Fascinated by the tale, Preston began to work with Spezi on the case. Here is the true story of their search to uncover and confront the man they believe is the Monster. In an ironic twist of fate that echoes the dark traditions of the city's bloody history, Preston and Spezi themselves became targets of ENTITY 2: Blasphemy Blasphemy is a novel by Douglas Preston that was released on January 8, 2008 by Forge Books. It is the
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to kia niro 2018?  [TURN_SEP]  Toyota prius_prime 2018  [TURN_SEP]  What's the name of the engine? ENTITY 1: Kia niro 2018 ENTITY 2: Toyota prius_prime 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to chevrolet volt 2017?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Chevrolet volt 2017  The 2017 Chevrolet Volt marks the second year of production for the redesigned model, but last year's redesigned Volt was only available on a limited basis.As such, many shoppers may not be aware of the changes that the second-generation Volt incorporates.... ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which competition makes up ix south american games?  [TURN_SEP]  Canoeing at the 2010 south american games – women's k-1 1000 metres  [TURN_SEP]  What was the preceded event? ENTITY 1: IX South American Games  The IX South American Games (Spanish: Juegos Sudamericanos, Portuguese: Jogos Sul-Americanos) was a multi-sport event held between 19–30 March 2010 in Medellín, Colombia. The Games were organized by the South American Sports Organization (ODESUR), who awarded the Games to the city with 8 votes over the bid by previous host Santiago, Chile (6 votes). ENTITY 2: Canoeing at the 2010 south american games – women's k-1 1000 metres  The Women's K-1 1000m event at the 2010 South American Games was held over March 27 at 9:00.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the name of the competition making 2009 world aquatics championships  [TURN_SEP]  Swimming at the 2009 world aquatics championships – women's 200 metre freestyle  [TURN_SEP]  What was the name of the event that preceded this event? ENTITY 1: 2009 World Aquatics Championships  The 2009 World Aquatics Championships or the XIII FINA World Championships were held in Rome, Italy from July 17 to August 2, 2009. The 2009 Championships featured competition in all 5 aquatics disciplines: diving, swimming, open water swimming, synchronized swimming and water polo. Rome won the right to stage the event on July 16, 2005 in Montreal, Canada. Rome defeated rival bids from Athens, Moscow and Yokohama. A record 2556 athletes from 185 countries participated. FINA's decision to allow the use of polyurethane suits caused these Championships to be dubbed the Plastic Games. ENTITY 2: Swimming at the 2009 world aquatics championships – women's 200 metre freestyle  The heats for the women's 200 m freestyle race at the 2009 World Championships took place in the morning and evening of 28 July and the final took place in the evening session of 29 July at the Foro Italico in Rome, Italy.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the trim level of acura ilx 2014  [TURN_SEP]  Acura ilx hybrid 2014  [TURN_SEP]  What was the name of the drivetrain? ENTITY 1: Acura ilx 2014  3 star ENTITY 2: Acura ilx hybrid 2014
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does kia niro 2018 correspond?  [TURN_SEP]  Toyota prius 2018  [TURN_SEP]  What was the engine used? ENTITY 1: Kia niro 2018 ENTITY 2: Toyota prius 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does mazda millenia 1995 correspond?  [TURN_SEP]  Honda clarity 2018  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Mazda millenia 1995 ENTITY 2: Honda clarity 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who is the parent of jacomina verhelst  [TURN_SEP]  Marinus verhelst  [TURN_SEP]  Who is the sibling? ENTITY 1: Jacomina Verhelst ENTITY 2: Marinus verhelst
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to chevrolet volt 2012?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  What's the name of the engine? ENTITY 1: Chevrolet volt 2012  The 2012 Chevrolet Volt is available nationwide after the 2011 model was offered in seven states and the District of Columbia. For 2012, the suggested retail price for Volt starts at $39,995 including destination charge which is more than $1000 less than the 2011 model. The 2012 Volt features standard keyless entry with passive locking, OnStar Turn by Turn navigation standard for three years, standard AM/FM/CD/MP3 with 7-inch color touchscreen and available 17-inch alloy wheels with black inserts. ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is higher classification for stephanandra  [TURN_SEP]  Neillieae  [TURN_SEP]  Biologically speaking, what is the classification? ENTITY 1: Stephanandra  Neillia is a genus of the botanical family Rosaceae. It is named for Patrick Neill. ENTITY 2: Neillieae  Neillieae is a tribe of flowering plants in rose family and the Amygdaloideae subfamily. It includes the genera Physocarpus, Neillia, and Stephanandra.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to chevrolet volt 2014?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Chevrolet volt 2014  The 2014 Chevrolet Volt remains unchanged from 2013, but drops in price by $5000 to lure in eco-conscious buyers. ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: What is capital name of kvænangen  [TURN_SEP]  Burfjord  [TURN_SEP]  What is the time zone? ENTITY 1: Kvænangen  Kvænangen (Northern Sami: Návuona suohkan, Kven: Naavuonon komuuni) is a municipality in Troms county, Norway. The administrative centre of the municipality is the village of Burfjord. The European route E6 highway goes through the municipality and over the Sørstraumen Bridge, and many people stop at the Kvænangsfjellet pass to view the scenery of the Kvænangen fjord. ENTITY 2: Burfjord  Burfjord (Kven: Puruvuono, Northern Sami: Buvrovuotna) is a village that is the administrative centre of Kvænangen Municipality in Troms county, Norway. It is home to the municipal council of Kvænangen. The 0.54-square-kilometre (130-acre) village has a population (2017) of 405 which gives the village a population density of 750 inhabitants per square kilometre (1,900/sq mi).
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the trim level of chevrolet malibu 2018  [TURN_SEP]  Chevrolet malibu hybrid 2018  [TURN_SEP]  What was the name of the drivetrain? ENTITY 1: Chevrolet malibu 2018 ENTITY 2: Chevrolet malibu hybrid 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does kia optima 2016 correspond?  [TURN_SEP]  2018 hyundai sonata hybrid  [TURN_SEP]  Name the engine used ENTITY 1: Kia optima 2016  The midsize sedan segment is filled with sedans so renowned that they need no introduction.Camry.Accord.Fusion.Even though the Kia Optima has been on sale in the United States since 2001, it only recently elevated itself from the bargain basement to become a serious competitor.... ENTITY 2: 2018 hyundai sonata hybrid
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the name of the competition making 2009 world aquatics championships  [TURN_SEP]  Swimming at the 2009 world aquatics championships – women's 200 metre individual medley  [TURN_SEP]  What was the preceded event? ENTITY 1: 2009 World Aquatics Championships  The 2009 World Aquatics Championships or the XIII FINA World Championships were held in Rome, Italy from July 17 to August 2, 2009. The 2009 Championships featured competition in all 5 aquatics disciplines: diving, swimming, open water swimming, synchronized swimming and water polo. Rome won the right to stage the event on July 16, 2005 in Montreal, Canada. Rome defeated rival bids from Athens, Moscow and Yokohama. A record 2556 athletes from 185 countries participated. FINA's decision to allow the use of polyurethane suits caused these Championships to be dubbed the Plastic Games. ENTITY 2: Swimming at the 2009 world aquatics championships – women's 200 metre individual medley  The first heats of the Women's 200m Individual Medley took place on the morning of Sunday, 26 July. The semifinal took place in the evening session of the same day and the final took place on the evening of the 27 July at the Foro Italico in Rome, Italy. The order of swimming in the medley was: Butterfly, backstroke, breaststroke, freestyle
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: Which is capital city for kunduz  [TURN_SEP]  Kunduz  [TURN_SEP]  In which time zone? ENTITY 1: Kunduz Kunduz is one of the 34 provinces of Afghanistan, located in the northern part of the country next to Tajikistan. The population of the province is around 953, 800, which is multi - ethnic and mostly a tribal society. The city of Kunduz serves as the capital of the province. The Kunduz Airport is located next to the provincial capital. The Kunduz River valley dominates the Kunduz Province. The river flows irregularly from south to north into the Amu Dar ENTITY 2: Kunduz Kunduz ( / kʊnduːz /, Pashto : کندز, Dari : قندوز ) is a city in northern Afghanistan, which serves as the capital of Kunduz Province. Kunduz has a population of about 268, 893, making it about the 6th - largest city of Afghanistan, while Kunduz District has a population of 304, 600. Located in the historical Tokharistan region of Bactria, Kunduz is linked by highways with Kabul to the south, Mazar - i - Sharif to the west, and Fayzabad, Badakhshan to the east. Kunduz is also linked with Qurghonteppa and Dushanbe in Tajikistan to the
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the name of the competition making ix south american games  [TURN_SEP]  Athletics at the 2010 south american games – women's discus throw  [TURN_SEP]  Which event took place before it? ENTITY 1: IX South American Games  The IX South American Games (Spanish: Juegos Sudamericanos, Portuguese: Jogos Sul-Americanos) was a multi-sport event held between 19–30 March 2010 in Medellín, Colombia. The Games were organized by the South American Sports Organization (ODESUR), who awarded the Games to the city with 8 votes over the bid by previous host Santiago, Chile (6 votes). ENTITY 2: Athletics at the 2010 south american games – women's discus throw  The Women's Discus Throw event at the 2010 South American Games was held on March 22 at 17:00.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which competition makes up xx commonwealth games?  [TURN_SEP]  Athletics at the 2014 commonwealth games – men's javelin throw  [TURN_SEP]  Which event took place before it? ENTITY 1: XX Commonwealth Games  The 2014 Commonwealth Games (Scottish Gaelic: Geamannan a' Cho-fhlaitheis 2014), officially known as the XX Commonwealth Games and commonly known as Glasgow 2014, (Scottish Gaelic: Glaschu 2014), was an international multi-sport event celebrated in the tradition of the Commonwealth Games as governed by the Commonwealth Games Federation (CGF). It took place in Glasgow, Scotland, from 23 July to 3 August 2014. ENTITY 2: Athletics at the 2014 commonwealth games – men's javelin throw  The Men's javelin throw at the 2014 Commonwealth Games as part of the athletics programme took place at Hampden Park between 1 and 2 August 2014.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the automative class related to bmw i3 2015?  [TURN_SEP]  Lexus ct 2015  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Bmw i3 2015 ENTITY 2: Lexus ct 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Name the competition making up ix south american games  [TURN_SEP]  Archery at the 2010 south american games – men's recurve 70m  [TURN_SEP]  What was the preceded event? ENTITY 1: IX South American Games  The IX South American Games (Spanish: Juegos Sudamericanos, Portuguese: Jogos Sul-Americanos) was a multi-sport event held between 19–30 March 2010 in Medellín, Colombia. The Games were organized by the South American Sports Organization (ODESUR), who awarded the Games to the city with 8 votes over the bid by previous host Santiago, Chile (6 votes). ENTITY 2: Archery at the 2010 south american games – men's recurve 70m  The Men's recurve 90m event at the 2010 South American Games was held on March 20 at 9:00.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to kia optima 2015?  [TURN_SEP]  2018 hyundai sonata hybrid  [TURN_SEP]  What's the name of the engine? ENTITY 1: Kia optima 2015  The 2015 Kia Optima receives an acoustic laminated windshield and repositioned cruise control buttons on LX, EX, SX, SX Turbo and SX-Limited trims. Other additions across the trims include new paint colors and an available black interior cloth combination. ENTITY 2: 2018 hyundai sonata hybrid
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the automative class related to ford focus 2016?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  What was the engine used? ENTITY 1: Ford focus 2016 ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who influenced billy squire?  [TURN_SEP]  Boston  [TURN_SEP]  Who was the supporting artist? ENTITY 1: Billy Squire  Billy Squier is a 68 year old American Musician. Born William Haislip Squier on 12th May, 1950 in Wellesley Hills, Massachusetts, USA, he is famous for The Stroke. His zodiac sign is Taurus. Billy Squier is a member of the following lists: Guitarists from Massachusetts, Musicians from Boston and American hard rock musicians. ENTITY 2: Boston  Boston is an American rock band from Boston, Massachusetts, that achieved its most notable successes during the 1970s and 1980s. Centered on guitarist, keyboardist, songwriter, and producer Tom Scholz, the band is a staple of classic rock radio playlists. Boston's best-known works include the songs More Than a Feeling, Peace of Mind, Foreplay/Long Time, Rock and Roll Band, Smokin', Don't Look Back, and Amanda. It has sold over 31 million albums in the United States, of which 17 million were for its self-titled debut album and seven million were for its second album, Don't Look Back. Altogether, the band has released six studio albums.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who is reponsible for influencing who?  [TURN_SEP]  Boston  [TURN_SEP]  Who was the supporting artist? ENTITY 1: Who  THE WHO HITS 50! UK 20CD Edition http://tinyurl.com/orw3krl UK 1-CD Edition http://tinyurl.com/m5yushj UK Digital Edition http://tinyurl.com/pebrya2 ENTITY 2: Boston  Boston is an American rock band from Boston, Massachusetts, that achieved its most notable successes during the 1970s and 1980s. Centered on guitarist, keyboardist, songwriter, and producer Tom Scholz, the band is a staple of classic rock radio playlists. Boston's best-known works include the songs More Than a Feeling, Peace of Mind, Foreplay/Long Time, Rock and Roll Band, Smokin', Don't Look Back, and Amanda. It has sold over 31 million albums in the United States, of which 17 million were for its self-titled debut album and seven million were for its second album, Don't Look Back. Altogether, the band has released six studio albums.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Moon of solar astronomy  [TURN_SEP]  15735 andakerkhoven  [TURN_SEP]  What is the spectral type for the astronomy? ENTITY 1: solar astronomy  The Sun is the star at the center of the Solar System. It is a nearly perfect sphere of hot plasma, with internal convective motion that generates a magnetic field via a dynamo process. It is by far the most important source of energy for life on Earth. Its diameter is about 1.39 million kilometers, i.e. 109 times that of Earth, and its mass is about 330,000 times that of Earth, accounting for about 99.86% of the total mass of the Solar System. About three quarters of the Sun's mass consists of hydrogen (~73%), the rest is mostly helium (~25%), with much smaller quantities of heavier elements, including oxygen, carbon, neon, and iron. ENTITY 2: 15735 andakerkhoven  15735 Andakerkhoven is a main-belt minor planet. It was discovered by Eric Walter Elst at the La Silla Observatory in Chile on November 18, 1990. It is named after Melisande Anda Kerkhoven, a medical student at the University of Groningen and participant in the Dutch resistance to Nazi Germany during World War II.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is spin off from sealab-2021  [TURN_SEP]  Sealab 2020  [TURN_SEP]  What was the title song called? ENTITY 1: Sealab-2021  An update of `Sealab 2020,' about underwater explorers. Using footage from the original show, this part of the Cartoon Network's `Adult Swim' offers up new dysfunctional characters beneath the sea. ENTITY 2: Sealab 2020  Cartoon adventure series that focused on a group of Oceanauts in their experimental complex on the ocean floor.
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: What is capital name of mondulkiri  [TURN_SEP]  Senmonorom  [TURN_SEP]  What is the time zone? ENTITY 1: Mondulkiri  Mondulkiri is a province of Cambodia. Bordering the provinces of Kratié to the west, Stung Treng to the northwest, Ratanakiri to the north and the country of Vietnam to the east and south, it is the most sparsely populated province in the country despite being the largest in land area. The province was created in 1961 from the eastern part of Kratié Province. The capital is the town of Senmonorom. ENTITY 2: Senmonorom  Senmonorom (Khmer: ក្រុងសែនមនោរម្យ Delightful) is the capital of Mondulkiri Province, Cambodia. It is the only major town in the province of Mondulkiri. The town has over 7000 inhabitants, and is often compared to frontier towns in the old American west.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who are the parents for hilmer berglund  [TURN_SEP]  Charlotta berglund  [TURN_SEP]  Which person is this person's brother or sister? ENTITY 1: Hilmer Berglund Lived at Sundsvik's Gård : http : / / www. svenskgeografi. se / laen / stockholm / 19052 - sundsvik. html SUNDSVIKS SÅGVERK, TEGELBRUK OCH KVARN Under 1600 - talet hade Nykvarns bruk en fabrik för tillverkning av koppar - och mässingsmide här. År l905 inköptes Sundsvik av bruksägaren Frans Albert Berglund och sedan denne år 1916 även inköpt Sundsör, hörde då båda gårdarna till samme ägare. Under Berglunds tid blevo både sågverk och tegelbruk ombyggda och mycket förbättrade samt nya arbetarebostäder uppförda. Såväl sågverk som tegelbruk utveck ENTITY 2:
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Mention the trim level of ford escape 2008  [TURN_SEP]  Ford escape hybrid 2008  [TURN_SEP]  What was the name of the drivetrain? ENTITY 1: Ford escape 2008  The 2008 Ford Escape receives a makeover inside and out featuring a bolder, rugged design, higher beltline, raised hood and a new front fascia with headlights that sweep up toward the front corners of the vehicle to short side marker lights. The interior features seating surfaces comprised of 100 percent post-industrial materials, a revised dashboard with “a top of dash” display, Electric Power Assisted Steering system, improved center console, Ice Blue interior lighting. A number of updates have been made to reduce noise, vibration and harshness levels inside the SUV including changes to the roof panel for a better airflow, a new acoustic laminate sandwiched between two glass panels in the windshield and new carpeting. Under the hood is a 2.3-liter 16-valve Duratec 23 4-cylinder engine that produces 153 horsepower and 152 lb-ft of torque mated to either a five-speed manual or four-speed automatic. Optional is a 200-horsepower 3.0-liter 24-valve V6. ENTITY 2: Ford escape hybrid 2008
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the sibling of angelo freschet  [TURN_SEP]  Filomena freschet  [TURN_SEP]  What is the name of the parent? ENTITY 1: Angelo FRESCHET  Angelo and his brother Giovanni came to California first. Angelo went back to Italy and was to come back to California with his wife, his brother and wife Luigi and Guisepina. Angelo's wife was very ill on the train to Genoa so they decided to cancel the travel and returned to San Fior. Luigi was rumored to have purchased a cow with the saved money. ENTITY 2: Filomena freschet
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which competition makes up ix south american games?  [TURN_SEP]  Diving at the 2010 south american games – women's 3 m synchro springboard  [TURN_SEP]  What was the preceded event? ENTITY 1: IX South American Games  The IX South American Games (Spanish: Juegos Sudamericanos, Portuguese: Jogos Sul-Americanos) was a multi-sport event held between 19–30 March 2010 in Medellín, Colombia. The Games were organized by the South American Sports Organization (ODESUR), who awarded the Games to the city with 8 votes over the bid by previous host Santiago, Chile (6 votes). ENTITY 2: Diving at the 2010 south american games – women's 3 m synchro springboard  The Women's 3m Synchronized Springboard event at the 2010 South American Games was held on March 22 at 15:00.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is prequel of the running man  [TURN_SEP]  Roadwork  [TURN_SEP]  Do you know the character of the book? ENTITY 1: The running man  The runaway bestseller about the ultimate reality show. The year is 2025. The Running Man is America's favorite television game show. Ben Richards is the program's latest contestant- and the Hunters' latest target in a rigged game of death. ENTITY 2: Roadwork  Roadwork is a novel by Stephen King, published in 1981 under the pseudonym Richard Bachman as a paperback original. It was collected in 1985 in the hardcover omnibus The Bachman Books, which is no longer in print. However, three of the four novels in that collection - Roadwork, The Long Walk, and The Running Man - have since been reprinted as standalone titles. The story takes place in an unnamed Midwestern city in 1973–1974. Grieving over the death of his son and the disintegration of his marriage, a man is driven to mental instability when he learns that both his home and his workplace will be demolished to make way for an extension to an interstate highway.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is sequel of str8men 1  [TURN_SEP]  Str8men 2  [TURN_SEP]  Mention the name of the director. ENTITY 1: Str8men 1 ENTITY 2: Str8men 2
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does chevrolet volt 2015 correspond?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  Name the engine used ENTITY 1: Chevrolet volt 2015  The 2015 Chevrolet Volt adds an in-car Wi-Fi hotspot with 4G LTE connection from OnStar, a new exterior color, and a battery storage increase to 17.1 kWh from 16.5. ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the automative class related to chevrolet volt 2018?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  Mention the name of the engine? ENTITY 1: Chevrolet volt 2018 ENTITY 2: Toyota prius_plug_in 2015
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Name the competition making up xx commonwealth games  [TURN_SEP]  Athletics at the 2014 commonwealth games – women's 100 metres hurdles  [TURN_SEP]  Which event took place before it? ENTITY 1: XX Commonwealth Games  The 2014 Commonwealth Games (Scottish Gaelic: Geamannan a' Cho-fhlaitheis 2014), officially known as the XX Commonwealth Games and commonly known as Glasgow 2014, (Scottish Gaelic: Glaschu 2014), was an international multi-sport event celebrated in the tradition of the Commonwealth Games as governed by the Commonwealth Games Federation (CGF). It took place in Glasgow, Scotland, from 23 July to 3 August 2014. ENTITY 2: Athletics at the 2014 commonwealth games – women's 100 metres hurdles  The Women's 100 metres hurdles at the 2014 Commonwealth Games, as part of the athletics programme, took place at Hampden Park on 31 July and 1 August 2014. Sally Pearson of Australia won the gold medal.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does bmw i8 2015 correspond?  [TURN_SEP]  Tesla model_s 2015  [TURN_SEP]  Name the engine used ENTITY 1: Bmw i8 2015 ENTITY 2: Tesla model_s 2015  The 2015 Tesla Model S 70D may be the company's entry-level model, but the performance from its twin electric motors has us seriously wowed.
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: What is name of capital city of bream bay  [TURN_SEP]  whangarei  [TURN_SEP]  Mention the time zone ENTITY 1: Bream Bay Bream Bay is a locality and bay on the east coast of New Zealand. Captain James Cook named this area to include the bay itself, but also some surrounding locations, stretching north to Whangarei and south to Mangawhai. However,'Bream Bay'is loosely used as a collaboration of the three major towns that satellite the main metropolitan area which are Ruakaka, One Tree Point and Waipu. The physical bay itself geographically spreads from the mouth of Whangarei Harbour, 22 kilometers south, to the southernmost point of Waipu Cove. The area also inhabits 3 native reserve islands, located just off the coast of Bream Bay : the Hen and Chickens Islands and Sail Rock Island ENTITY 2: whangarei Whangarei ( Māori : Whangārei - pronounced : Faa - ngaa - re - i ) is the major population centre of Northland and the northernmost city in the North Island of New Zealand with about 50, 000 residents. It has a warm semi - tropical climate, with summer daytime temperatures around 24 - 26°C, regular rainy days year round and mild winters that rarely have frosts and are mild enough for the region to be described as the winterless north
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the trim level of ford escape 2007?  [TURN_SEP]  Ford escape hybrid 2007  [TURN_SEP]  What was the name of the drivetrain? ENTITY 1: Ford escape 2007  The 2007 Ford Escape adds two appearance packages to the lineup, standard keypad entry on XLG Sport and Limited, three new exterior colors and an optional dealer-installed anti-theft wheel lock kit. The new XLT Sport package includes painted body-color bodyside cladding and bumpers wheel lip moldings. The Silver Appearance Package includes silver metallic fascias, bodyside cladding and wheel lip moldings. ENTITY 2: Ford escape hybrid 2007
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: State the name of the competition making ix south american games  [TURN_SEP]  Cycling at the 2010 south american games – women's road time trial  [TURN_SEP]  What was the name of the event that preceded this event? ENTITY 1: IX South American Games  The IX South American Games (Spanish: Juegos Sudamericanos, Portuguese: Jogos Sul-Americanos) was a multi-sport event held between 19–30 March 2010 in Medellín, Colombia. The Games were organized by the South American Sports Organization (ODESUR), who awarded the Games to the city with 8 votes over the bid by previous host Santiago, Chile (6 votes). ENTITY 2: Cycling at the 2010 south american games – women's road time trial  The Women's Time Trial event at the 2010 South American Games was held at 10:00 on March 17.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to cadillac elr 2016?  [TURN_SEP]  Tesla model_s 2015  [TURN_SEP]  What's the name of the engine? ENTITY 1: Cadillac elr 2016 ENTITY 2: Tesla model_s 2015  The 2015 Tesla Model S 70D may be the company's entry-level model, but the performance from its twin electric motors has us seriously wowed.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Which automative class corresponds to hyundai ioniq 2018?  [TURN_SEP]  Toyota prius 2018  [TURN_SEP]  What was the engine used? ENTITY 1: Hyundai ioniq 2018 ENTITY 2: Toyota prius 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Who are the mother and father for harriet elizabeth tucker  [TURN_SEP]  Georgiana augusta hawkins  [TURN_SEP]  Which person is this person's brother or sister? ENTITY 1: Harriet Elizabeth Tucker ENTITY 2: Georgiana augusta hawkins
#
# Predicted: no
# Gold: yes
# Text: CONTEXT: Where is judicial capital for la litera/la llitera  [TURN_SEP]  Binéfar  [TURN_SEP]  What is the time zone? ENTITY 1: La Litera/La Llitera  La Litera (Spanish: [la liˈteɾa]) or La Llitera (Catalan: [lə ʎiˈteɾə]) (Aragonese: A Litera) is an Aragonese comarca in the south-east of the province of Huesca. Its cultural capital is Tamarite de Litera, its administrative capital is Binefar and it borders the comarques of Ribagorza, Somontano de Barbastro, Cinca Medio, Bajo Cinca in Aragon and Noguera and Segrià in Catalonia. ENTITY 2: Binéfar  Binéfar (Spanish: [biˈnefaɾ]) is a municipality located in the province of Huesca, Aragon, Spain. According to the 2008 census (INE), the municipality has a population of 9,288 inhabitants. It is probably best known for the children's theatre group Los Titiriteros de Binéfar.
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: Mention the trim level of ford escape 2012  [TURN_SEP]  Ford escape hybrid 2012  [TURN_SEP]  What was the name of the drivetrain? ENTITY 1: Ford escape 2012  Ford's popular Escape crossover SUV carries over to the 2012 model year unchanged.The 2012 Ford Escape is likely the last we'll see of this body style since an all-new Ford compact crossover is expected to debut next year.The Ford Escape is notable among its competitors for having three engine choices suiting just about every conceivable need.... ENTITY 2: Ford escape hybrid 2012
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: To which automative class does hyundai ioniq 2017 correspond?  [TURN_SEP]  Toyota prius 2018  [TURN_SEP]  What was the engine used? ENTITY 1: Hyundai ioniq 2017 ENTITY 2: Toyota prius 2018
#
# Predicted: yes
# Gold: no
# Text: CONTEXT: What is the automative class related to kia niro 2018?  [TURN_SEP]  Toyota prius_plug_in 2015  [TURN_SEP]  Name the engine used ENTITY 1: Kia niro 2018 ENTITY 2: Toyota prius_plug_in 2015
