# %% [markdown]
# # Evaluation of ChatGPT Baseline on CLAQUA corpus

# %%
import pandas as pd
import numpy as np

# %%
cd /content/drive/MyDrive/thesis/chat-gpt_baseline
# Out:
# /content/drive/MyDrive/thesis/chat-gpt_baseline

# %% [markdown]
# ## Calculate metrics
# Metrics used for evaluation:
# - Accuracy
# - Precision
# - Recall
# - F1-score

# %%
def get_true_positives(df, prompt_label):
  true_positives = len(df[(df["label"]==1) &
                      (df[prompt_label]==1)])  # True positives
  return true_positives

def get_true_negatives(df, prompt_label):
  true_negatives = len(df[(df["label"]==0) &
                      (df[prompt_label]==0)])  # True negatives
  return true_negatives

def get_false_positives(df, prompt_label):
  false_positives = len(df[(df["label"]==0) &
                           (df[prompt_label]==1)])  # False positives
  return false_positives

def get_false_negatives(df, prompt_label):
  false_negatives = len(df[(df["label"]==1) &
                       (df[prompt_label]==0)])  # False negatives
  return false_negatives

def calculate_accuracy(true_positives, false_positives, true_negatives, false_negatives):
  return (true_positives + true_negatives) / (true_positives + true_negatives + false_positives + false_negatives)

def calculate_precision(true_positives, false_positives):
  return true_positives / (true_positives + false_positives)

def calculate_recall(true_positives, false_negatives):
  return true_positives / (true_positives + false_negatives)

def calculate_f1_score(precision, recall):
  return 2 * (precision * recall) / (precision+recall)

# %%
def evaluate(df, prompt_eval):
  TP = get_true_positives(df, prompt_eval)
  FP = get_false_positives(df, prompt_eval)
  TN = get_true_negatives(df, prompt_eval)
  FN = get_false_negatives(df, prompt_eval)

  accuracy = calculate_accuracy(TP, FP, TN, FN)
  precision = calculate_precision(TP, FP)
  recall = calculate_recall(TP, FN)
  f1_score = calculate_f1_score(precision, recall)

  print(f"\t Accuracy: {accuracy}")
  print(f"\t Precision: {precision}")
  print(f"\t Recall: {recall}")
  print(f"\t F1 score: {f1_score}")

  return accuracy, precision, recall, f1_score

# %%
def evaluate_explanations(df, prompt_eval_explanation_based):
  # calculate percentage of correct explanations (only for the correctly predicted labels)
  return len(df[df[prompt_eval_explanation_based]=="correct"]) / (len(df[df[prompt_eval_explanation_based]=="correct"]) + len(df[df[prompt_eval_explanation_based]=="incorrect"]) )

# %%
def evaluate_hallucinations_omissions_incoherence(df, prompt_eval_type):
  # calculate percentage of hallucinations / omissions / incoherence / focus deviations
  return len(df[df[prompt_eval_type]==1]) / (len(df[df[prompt_eval_type]==0]) + len(df[df[prompt_eval_type]==1]) )

# %% [markdown]
# ## Single-turn Results Evaluation

# %%
single_turn_gpt_results_path = './single_turn_test_sample_evaluated.csv'

# %%
from ast import literal_eval
single_turn_gpt_results = pd.read_csv(single_turn_gpt_results_path, delimiter=';', header=0, converters={'attrs_entity1' : literal_eval, 'attrs_entity2' : literal_eval})
single_turn_gpt_results = single_turn_gpt_results.drop(columns=['Unnamed: 0','Unnamed: 0.1', 'Unnamed: 0.2', 'Unnamed: 0.3', 'Unnamed: 0.4', 'Unnamed: 0.5'])

# %%
single_turn_gpt_results
# Out:
#     sample_index  corpus_index  label  \
# 0              0           661      0
# 1              1           427      1
# 2              2           192      0
# 3              3           209      0
# 4              4           738      0
# ..           ...           ...    ...
# 95            95           482      0
# 96            96           764      0
# 97            97           328      1
# 98            98           156      0
# 99            99           933      1
#
#                                               context  \
# 0        specify the name of the release of Farewell?
# 1                First person to summit Mount Olympus
# 2          state the sports statistics of Will Brooks
# 3   mention where Palookaville can be purchased on...
# 4           What was the set location of Blood of Man
# ..                                                ...
# 95  What is the name of the musical composition wh...
# 96     Which software was developed by Rusty Russell?
# 97  What video corresponds to How the States Got T...
# 98   what is the creative work about The Crimean War?
# 99            What kind of descriptor is Illumination
#
#                                               entity1  \
# 0   Farewell  Farewell is a live album by jazz com...
# 1   Mount Olympus  Mount Olympus (/oʊˈlɪmpəs, əˈlɪ...
# 2   Will Brooks  Will Brooks is an actor, known fo...
# 3   Palookaville  Palookaville is a comic book wri...
# 4   Blood of Man  Blood of Man is the eighth album...
# ..                                                ...
# 95  Band of the Hand  Band of the Hand is an Ameri...
# 96  Rusty Russell  William Rusty Russell (born Aug...
# 97  How the States Got Their Shapes  Correspondent...
# 98  The Crimean War  The Crimean War, also known i...
# 99  Illumination  Illumination is an album by R&B ...
#
#                                               entity2  \
# 0   Farewell  Farewell is an American pop punk ban...
# 1   Mount Olympus  Mount Olympus, at 7,980 feet, i...
# 2                   Will Brooks  mixed martial artist
# 3   Palookaville  Palookaville is the fourth studi...
# 4   Blood of Man  Charlie, a compulsive liar, and ...
# ..                                                ...
# 95  Band of the Hand  Band of the Hand is the 1986...
# 96  Rusty Russell  Paul Rusty Russell is an Austra...
# 97  How the States Got Their Shapes  Every shape o...
# 98  The Crimean War  During the Crimean War, for t...
# 99  Illumination  Illumination is the fifth full-l...
#
#                                           prompt2_out  prompt2_label  \
# 0   The user question needs a clarification reques...              1
# 1   The user question needs a clarification reques...              1
# 2   The user question needs a clarification reques...              1
# 3   The user question needs a clarification reques...              1
# 4   The user question needs a clarification reques...              1
# ..                                                ...            ...
# 95  The user question does not need a clarificatio...              0
# 96  The user question needs a clarification reques...              1
# 97  The user question does not need a clarificatio...              0
# 98  The user question does not need a clarificatio...              0
# 99  The user question needs a clarification reques...              1
#
#    prompt2_eval_label-based prompt2_eval_explanation-based  ...  \
# 0                 incorrect                              -  ...
# 1                   correct                        correct  ...
# 2                 incorrect                              -  ...
# 3                 incorrect                              -  ...
# 4                 incorrect                              -  ...
# ..                      ...                            ...  ...
# 95                  correct                      incorrect  ...
# 96                incorrect                              -  ...
# 97                incorrect                              -  ...
# 98                  correct                      incorrect  ...
# 99                  correct                        correct  ...
#
#    prompt1_eval_hallucination  prompt1_eval_omission prompt1_eval_incoherence  \
# 0                           0                      1                        1
# 1                           0                      1                        0
# 2                           0                      0                        0
# 3                           0                      0                        0
# 4                           1                      1                        0
# ..                        ...                    ...                      ...
# 95                          0                      0                        0
# 96                          0                      0                        0
# 97                          0                      1                        0
# 98                          0                      0                        0
# 99                          0                      0                        0
#
#    prompt2_eval_hallucination prompt2_eval_omission  prompt2_eval_incoherence  \
# 0                           1                     1                         0
# 1                           0                     0                         0
# 2                           0                     0                         0
# 3                           1                     0                         0
# 4                           0                     1                         0
# ..                        ...                   ...                       ...
# 95                          0                     1                         1
# 96                          0                     1                         0
# 97                          1                     1                         0
# 98                          0                     1                         0
# 99                          0                     1                         0
#
#     prompt1_eval_focus-deviation  prompt2_eval_focus-deviation  \
# 0                              1                             0
# 1                              1                             0
# 2                              1                             0
# 3                              0                             0
# 4                              1                             0
# ..                           ...                           ...
# 95                             1                             0
# 96                             1                             0
# 97                             1                             0
# 98                             1                             0
# 99                             1                             0
#
#                                         attrs_entity1  \
# 0   [commerce.product, media_common.cataloged_inst...
# 1   [location.location, fictional_universe.setting...
# 2   [biology.organism, event.agent, film.actor, me...
# 3             [book.written_work, comic_books.series]
# 4   [media_common.cataloged_instance, music.album,...
# ..                                                ...
# 95  [media_common.creative_work, ratings.rated_ent...
# 96  [media_common.cataloged_instance, people.perso...
# 97  [tv.program, ratings.rated_entity, media_commo...
# 98  [book.subject, film.subject, media_common.subj...
# 99  [award.nominated_work, commerce.consumer_produ...
#
#                                         attrs_entity2
# 0   [event.agent, internet.social_network_user, me...
# 1   [geography.geographical_feature, geography.mou...
# 2   [martial_arts.martial_artist, media_common.cat...
# 3   [award.nominated_work, commerce.consumer_produ...
# 4   [media_common.creative_work, film.film, media_...
# ..                                                ...
# 95  [media_common.creative_work, music.album, musi...
# 96  [computer.software_developer, people.person, b...
# 97  [media_common.creative_work, ratings.rated_ent...
# 98  [media_common.creative_work, ratings.rated_ent...
# 99  [music.album, commerce.consumer_product, comme...
#
# [100 rows x 26 columns]

# %%
num_negative_items = len(single_turn_gpt_results[single_turn_gpt_results["label"]==0])  # Number of corpus items without clarification need
num_positive_items = len(single_turn_gpt_results[single_turn_gpt_results["label"]==1])  # Number of corpus items with clarification need
num_total = len(single_turn_gpt_results)
print(num_total)
# Out:
# 100

# %%
print("Single-turn Evaluation")
print('\n')
# Label evaluation
print(f"Prompt0 Evaluation Label-based")
prompt0_yn_eval_acc, prompt0_yn_eval_precision, prompt0_yn_eval_recall, prompt0_yn_eval_f1 = evaluate(single_turn_gpt_results, "prompt0_label")
print(f"Prompt1 Evaluation Label-based")
prompt1_yn_eval_acc, prompt1_yn_eval_precision, prompt1_yn_eval_recall, prompt1_yn_eval_f1 = evaluate(single_turn_gpt_results, "prompt1_label")
print(f"Prompt2 Evaluation Label-based")
prompt2_yn_eval_acc, prompt2_yn_eval_precision, prompt2_yn_eval_recall, prompt2_yn_eval_f1 = evaluate(single_turn_gpt_results, "prompt2_label")

print('\n')
# Explanation evaluation
prompt1_correct_expl = evaluate_explanations(single_turn_gpt_results, "prompt1_eval_explanation-based")
print(f"Prompt1 Evaluation Explanation-based \n\t Percentage of correct explanations (only for the correctly predicted labels): {prompt1_correct_expl:.1%}")
prompt2_correct_expl = evaluate_explanations(single_turn_gpt_results, "prompt2_eval_explanation-based")
print(f"Prompt2 Evaluation Explanation-based \n\t Percentage of correct explanations (only for the correctly predicted labels): {prompt2_correct_expl:.1%}")

print('\n')
# Prompt hallucination / omission / incoherence / focus deviation evaluation
prompt1_focus_deviations = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt1_eval_focus-deviation')
print(f"Prompt1 Evaluation \n\t Percentage of focus deviations: {prompt1_focus_deviations:.1%}")
prompt1_hallucinations = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt1_eval_hallucination')
print(f"\t Percentage of hallucinations: {prompt1_hallucinations:.1%}")
prompt1_omissions = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt1_eval_omission')
print(f"\t Percentage of omissions: {prompt1_omissions:.1%}")
prompt1_incoherence = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt1_eval_incoherence')
print(f"\t Percentage of incoherences: {prompt1_incoherence:.1%}")
prompt2_focus_deviations = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt2_eval_focus-deviation')
print(f"Prompt2 Evaluation \n\t Percentage of focus deviations: {prompt2_focus_deviations:.1%}")
prompt2_hallucinations = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt2_eval_hallucination')
print(f"\t Percentage of hallucinations: {prompt2_hallucinations:.1%}")
prompt2_omissions = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt2_eval_omission')
print(f"\t Percentage of omissions: {prompt2_omissions:.1%}")
prompt2_incoherence = evaluate_hallucinations_omissions_incoherence(single_turn_gpt_results, 'prompt2_eval_incoherence')
print(f"\t Percentage of incoherences: {prompt2_incoherence:.1%}")
# Out:
# Single-turn Evaluation
#
#
# Prompt0 Evaluation Label-based
# 	 Accuracy: 0.48
# 	 Precision: 0.38636363636363635
# 	 Recall: 0.40476190476190477
# 	 F1 score: 0.3953488372093023
# Prompt1 Evaluation Label-based
# 	 Accuracy: 0.41
# 	 Precision: 0.4105263157894737
# 	 Recall: 0.9285714285714286
# 	 F1 score: 0.5693430656934306
# Prompt2 Evaluation Label-based
# 	 Accuracy: 0.46
# 	 Precision: 0.35714285714285715
# 	 Recall: 0.35714285714285715
# 	 F1 score: 0.35714285714285715
#
#
# Prompt1 Evaluation Explanation-based
# 	 Percentage of correct explanations (only for the correctly predicted labels): 22.5%
# Prompt2 Evaluation Explanation-based
# 	 Percentage of correct explanations (only for the correctly predicted labels): 56.5%
#
#
# Prompt1 Evaluation
# 	 Percentage of focus deviations: 91.0%
# 	 Percentage of hallucinations: 9.0%
# 	 Percentage of omissions: 36.0%
# 	 Percentage of incoherences: 5.0%
# Prompt2 Evaluation
# 	 Percentage of focus deviations: 3.0%
# 	 Percentage of hallucinations: 18.0%
# 	 Percentage of omissions: 64.0%
# 	 Percentage of incoherences: 13.0%

# %% [markdown]
# #### Calculate metrics only for examples which are not unclear
# Some corpus items have gold labels which are not self-explanatory. These are labeled as "unclear" and in the following taken out from the dataset for evaluation.

# %%
single_turn_gpt_results_clear =  single_turn_gpt_results[single_turn_gpt_results["label_comment"]!="unclear"]
print(f"Number of items in test subset single-turn with verifiable label given entity text descriptions: {len(single_turn_gpt_results_clear)}")
# Out:
# Number of items in test subset single-turn with verifiable label given entity text descriptions: 66

# %%
print(f"Prompt1 Evaluation Yes-no-based (only test items with verifiable label given entity text descriptions)")
prompt1_yn_eval_acc, prompt1_yn_eval_precision, prompt1_yn_eval_recall, prompt1_yn_eval_f1 = evaluate(single_turn_gpt_results_clear, "prompt1_label")
print(f"Prompt2 Evaluation Yes-no-based (only test items with verifiable label given entity text descriptions)")
prompt2_yn_eval_acc, prompt2_yn_eval_precision, prompt2_yn_eval_recall, prompt2_yn_eval_f1 = evaluate(single_turn_gpt_results_clear, "prompt2_label")
# Out:
# Prompt1 Evaluation Yes-no-based (only test items with verifiable label given entity text descriptions)
# 	 Accuracy: 0.5757575757575758
# 	 Precision: 0.5967741935483871
# 	 Recall: 0.925
# 	 F1 score: 0.7254901960784315
# Prompt2 Evaluation Yes-no-based (only test items with verifiable label given entity text descriptions)
# 	 Accuracy: 0.3939393939393939
# 	 Precision: 0.5
# 	 Recall: 0.325
# 	 F1 score: 0.393939393939394

# %% [markdown]
# #### Calculate number of prompt1 responses for positive clarification need

# %%
num_positive_predicted_prompt1 = len(single_turn_gpt_results[single_turn_gpt_results['prompt1_out'].str.contains('^Yes')])
num_negative_predicted_prompt1 = len(single_turn_gpt_results[single_turn_gpt_results['prompt1_out'].str.contains('^No',regex=True)])
assert num_positive_predicted_prompt1 + num_negative_predicted_prompt1 == len(single_turn_gpt_results) # check for double counting
print(f"Single-turn: Percentage of prompt1 responses predicting clarification need (class 1): {(num_positive_predicted_prompt1/len(single_turn_gpt_results))*100}%")
print(f"Single-turn: Percentage of prompt1 responses predicting no clarification need (class 0): {(num_negative_predicted_prompt1/len(single_turn_gpt_results))*100}%")
# Out:
# Single-turn: Percentage of prompt1 responses predicting clarification need (class 1): 95.0%
# Single-turn: Percentage of prompt1 responses predicting no clarification need (class 0): 5.0%

# %% [markdown]
# ## Multi-turn Results Evaluation

# %%
multi_turn_gpt_results_path = './multi_turn_test_sample_evaluated.csv'

# %%
multi_turn_gpt_results = pd.read_csv(multi_turn_gpt_results_path, delimiter=';', header=0, converters={'attrs_entity1' : literal_eval, 'attrs_entity2' : literal_eval})
multi_turn_gpt_results = multi_turn_gpt_results.drop(columns=['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.2', 'Unnamed: 0.3'])

# %%
num_negative_items = len(multi_turn_gpt_results[multi_turn_gpt_results["label"]==0])  # Number of corpus items without clarification need
num_positive_items = len(multi_turn_gpt_results[multi_turn_gpt_results["label"]==1])  # Number of corpus items with clarification need
num_total = len(multi_turn_gpt_results)
print(num_total)
# Out:
# 100

# %%
print("Multi-turn Evaluation")
print('\n')
# Label evaluation
print(f"Prompt0 Evaluation Label-based")
prompt0_yn_eval_acc, prompt0_yn_eval_precision, prompt0_yn_eval_recall, prompt0_yn_eval_f1 = evaluate(multi_turn_gpt_results, "prompt0_label")
print(f"Prompt1 Evaluation Label-based")
prompt1_yn_eval_acc, prompt1_yn_eval_precision, prompt1_yn_eval_recall, prompt1_yn_eval_f1 = evaluate(multi_turn_gpt_results, "prompt1_label")
print(f"Prompt2 Evaluation Label-based")
prompt2_yn_eval_acc, prompt2_yn_eval_precision, prompt2_yn_eval_recall, prompt2_yn_eval_f1 = evaluate(multi_turn_gpt_results, "prompt2_label")
print(f"Prompt3 Evaluation Label-based")
prompt3_yn_eval_acc, prompt3_yn_eval_precision, prompt3_yn_eval_recall, prompt3_yn_eval_f1 = evaluate(multi_turn_gpt_results, "prompt3_label")

print('\n')
# Explanation evaluation
prompt1_correct_expl = evaluate_explanations(multi_turn_gpt_results, "prompt1_eval_explanation-based")
print(f"Prompt1 Evaluation Explanation-based \n\t Percentage of correct explanations (only for the correctly predicted labels): {prompt1_correct_expl:.1%}")
prompt2_correct_expl = evaluate_explanations(multi_turn_gpt_results, "prompt2_eval_explanation-based")
print(f"Prompt2 Evaluation Explanation-based \n\t Percentage of correct explanations (only for the correctly predicted labels): {prompt2_correct_expl:.1%}")
prompt3_correct_expl = evaluate_explanations(multi_turn_gpt_results, "prompt3_eval_explanation-based")
print(f"Prompt3 Evaluation Explanation-based \n\t Percentage of correct explanations (only for the correctly predicted labels): {prompt3_correct_expl:.1%}")

print('\n')
# Prompt hallucination / omission / incoherence / focus deviation evaluation
prompt1_focus_deviations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt1_eval_focus-deviation')
print(f"Prompt1 Evaluation \n\t Percentage of focus deviations: {prompt1_focus_deviations:.1%}")
prompt1_hallucinations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt1_eval_hallucination')
print(f"\t Percentage of hallucinations: {prompt1_hallucinations:.1%}")
prompt1_omissions = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt1_eval_omission')
print(f"\t Percentage of omissions: {prompt1_omissions:.1%}")
prompt1_incoherence = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt1_eval_incoherence')
print(f"\t Percentage of incoherences: {prompt1_incoherence:.1%}")
prompt2_focus_deviations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt2_eval_focus-deviation')
print(f"Prompt2 Evaluation \n\t Percentage of focus deviations: {prompt2_focus_deviations:.1%}")
prompt2_hallucinations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt2_eval_hallucination')
print(f"\t Percentage of hallucinations: {prompt2_hallucinations:.1%}")
prompt2_omissions = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt2_eval_omission')
print(f"\t Percentage of omissions: {prompt2_omissions:.1%}")
prompt2_incoherence = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt2_eval_incoherence')
print(f"\t Percentage of incoherences: {prompt2_incoherence:.1%}")
prompt3_focus_deviations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt3_eval_focus-deviation')
print(f"Prompt2 Evaluation \n\t Percentage of focus deviations: {prompt3_focus_deviations:.1%}")
prompt3_hallucinations = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt3_eval_hallucination')
print(f"\t Percentage of hallucinations: {prompt3_hallucinations:.1%}")
prompt3_omissions = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt3_eval_omission')
print(f"\t Percentage of omissions: {prompt3_omissions:.1%}")
prompt3_incoherence = evaluate_hallucinations_omissions_incoherence(multi_turn_gpt_results, 'prompt3_eval_incoherence')
print(f"\t Percentage of incoherences: {prompt3_incoherence:.1%}")
# Out:
# Multi-turn Evaluation
#
#
# Prompt0 Evaluation Label-based
# 	 Accuracy: 0.56
# 	 Precision: 0.8888888888888888
# 	 Recall: 0.1568627450980392
# 	 F1 score: 0.26666666666666666
# Prompt1 Evaluation Label-based
# 	 Accuracy: 0.52
# 	 Precision: 0.5151515151515151
# 	 Recall: 1.0
# 	 F1 score: 0.6799999999999999
# Prompt2 Evaluation Label-based
# 	 Accuracy: 0.49
# 	 Precision: 0.5
# 	 Recall: 0.6666666666666666
# 	 F1 score: 0.5714285714285715
# Prompt3 Evaluation Label-based
# 	 Accuracy: 0.47
# 	 Precision: 0.47368421052631576
# 	 Recall: 0.35294117647058826
# 	 F1 score: 0.40449438202247195
#
#
# Prompt1 Evaluation Explanation-based
# 	 Percentage of correct explanations (only for the correctly predicted labels): 9.6%
# Prompt2 Evaluation Explanation-based
# 	 Percentage of correct explanations (only for the correctly predicted labels): 30.6%
# Prompt3 Evaluation Explanation-based
# 	 Percentage of correct explanations (only for the correctly predicted labels): 41.3%
#
#
# Prompt1 Evaluation
# 	 Percentage of focus deviations: 94.0%
# 	 Percentage of hallucinations: 5.0%
# 	 Percentage of omissions: 22.0%
# 	 Percentage of incoherences: 2.0%
# Prompt2 Evaluation
# 	 Percentage of focus deviations: 64.0%
# 	 Percentage of hallucinations: 18.0%
# 	 Percentage of omissions: 26.0%
# 	 Percentage of incoherences: 20.0%
# Prompt2 Evaluation
# 	 Percentage of focus deviations: 27.0%
# 	 Percentage of hallucinations: 23.0%
# 	 Percentage of omissions: 35.0%
# 	 Percentage of incoherences: 4.0%

# %% [markdown]
# #### Calculate metrics only for examples which are not unclear
# Some corpus items have gold labels which are not self-explanatory. These are labeled as "unclear" and in the following taken out from the dataset for evaluation.

# %%
multi_turn_gpt_results_clear = multi_turn_gpt_results[multi_turn_gpt_results["label_comment"]!="unclear"]
print(f"Number of items in test subset multi-turn with verifiable label given entity text descriptions: {len(multi_turn_gpt_results_clear)}")
# Out:
# Number of items in test subset multi-turn with verifiable label given entity text descriptions: 76

# %%
print(f"Prompt1 Evaluation Label-based (only test items with verifiable label given entity text descriptions)")
prompt1_yn_eval_acc, prompt1_yn_eval_precision, prompt1_yn_eval_recall, prompt1_yn_eval_f1 = evaluate(multi_turn_gpt_results_clear, "prompt1_label")
print(f"Prompt2 Evaluation Label-based (only test items with verifiable label given entity text descriptions)")
prompt2_yn_eval_acc, prompt2_yn_eval_precision, prompt2_yn_eval_recall, prompt2_yn_eval_f1 = evaluate(multi_turn_gpt_results_clear, "prompt2_label")
print(f"Prompt3 Evaluation Label-based (only test items with verifiable label given entity text descriptions)")
prompt3_yn_eval_acc, prompt3_yn_eval_precision, prompt3_yn_eval_recall, prompt3_yn_eval_f1 = evaluate(multi_turn_gpt_results_clear, "prompt3_label")
# Out:
# Prompt1 Evaluation Label-based (only test items with verifiable label given entity text descriptions)
# 	 Accuracy: 0.6447368421052632
# 	 Precision: 0.64
# 	 Recall: 1.0
# 	 F1 score: 0.7804878048780487
# Prompt2 Evaluation Label-based (only test items with verifiable label given entity text descriptions)
# 	 Accuracy: 0.5333333333333333
# 	 Precision: 0.625
# 	 Recall: 0.6382978723404256
# 	 F1 score: 0.631578947368421
# Prompt3 Evaluation Label-based (only test items with verifiable label given entity text descriptions)
# 	 Accuracy: 0.4342105263157895
# 	 Precision: 0.5925925925925926
# 	 Recall: 0.3333333333333333
# 	 F1 score: 0.4266666666666667

# %% [markdown]
# #### Calculate number of prompt1 responses for positive clarification need

# %%
num_positive_predicted_prompt1 = len(multi_turn_gpt_results[multi_turn_gpt_results['prompt1_out'].str.contains('^Yes')])
num_negative_predicted_prompt1 = len(multi_turn_gpt_results[multi_turn_gpt_results['prompt1_out'].str.contains('^No',regex=True)])
assert num_positive_predicted_prompt1 + num_negative_predicted_prompt1 == len(multi_turn_gpt_results) # check for double counting
print(f"Multi-turn: Percentage of prompt1 responses predicting clarification need (class 1): {(num_positive_predicted_prompt1/len(multi_turn_gpt_results))*100}%")
print(f"Multi-turn: Percentage of prompt1 responses predicting no clarification need (class 0): {(num_negative_predicted_prompt1/len(multi_turn_gpt_results))*100}%")
# Out:
# Multi-turn: Percentage of prompt1 responses predicting clarification need (class 1): 99.0%
# Multi-turn: Percentage of prompt1 responses predicting no clarification need (class 0): 1.0%

# %%
multi_turn_gpt_results[multi_turn_gpt_results['prompt1_out'].str.contains('^No',regex=True)]
# Out:
#     Unnamed: 0.4  sample_index  corpus_index  label  \
# 28            28            28           736      0
#
#                                               context  \
# 28  What is sequel of real steel <EOS> Real steel ...
#
#                                               entity1  \
# 28  Real Steel  A struggling fighter-turned-promot...
#
#                                               entity2  \
# 28  Real steel 2  Real Steel 2 is an upcoming scie...
#
#                                           prompt1_out  prompt1_label  \
# 28  No, the user question does not need a clarific...              0
#
#    prompt1_eval_label-based  ... prompt2_eval_focus-deviation  \
# 28                  correct  ...                            1
#
#    prompt2_eval_hallucination  prompt2_eval_omission prompt2_eval_incoherence  \
# 28                          0                      0                        0
#
#    prompt3_eval_focus-deviation prompt3_eval_hallucination  \
# 28                            1                          0
#
#    prompt3_eval_omission  prompt3_eval_incoherence  \
# 28                     1                         0
#
#                                         attrs_entity1  \
# 28  [media_common.adaptation, broadcast.content, a...
#
#                                         attrs_entity2
# 28  [ratings.rated_entity, film.film, media_common...
#
# [1 rows x 35 columns]

# %% [markdown]
# # Random baseline
# Set up a random baseline on the data for result comparison.
#
# Sklearn Dummy Classifier see documentation: https://scikit-learn.org/stable/modules/generated/sklearn.dummy.DummyClassifier.html
# Strategies used:
# - “uniform”: generates predictions uniformly at random from the list of unique classes observed in y, i.e. each class has equal probability.
# - “most_frequent”: the predict method always returns the most frequent class label in the observed y argument passed to fit

# %%
from sklearn.dummy import DummyClassifier

# %% [markdown]
# ### Single-turn

# %%
x_values_pandas_single_turn = single_turn_gpt_results["context"] + " " + single_turn_gpt_results["entity1"] + " " + single_turn_gpt_results["entity2"]
x_values_single_turn = x_values_pandas_single_turn.to_numpy()
y_values_single_turn = single_turn_gpt_results["label"].to_numpy()

# create dummy classifier
dummy_clf_uniform = DummyClassifier(strategy='uniform', random_state=42)
dummy_clf_mostfreq = DummyClassifier(strategy='most_frequent', random_state=42)
# train a model
dummy_clf_uniform.fit(x_values_single_turn, y_values_single_turn)
dummy_clf_mostfreq.fit(x_values_single_turn, y_values_single_turn)
# get accuracy score
print(f"Dummy classifier on single-turn data, strategy uniform, accuracy: {dummy_clf_uniform.score(x_values_single_turn, y_values_single_turn)}")
print(f"Dummy classifier on single-turn data, strategy most-frequent, accuracy: {dummy_clf_mostfreq.score(x_values_single_turn, y_values_single_turn)}")
# Out:
# Dummy classifier on single-turn data, strategy uniform, accuracy: 0.46
# Dummy classifier on single-turn data, strategy most-frequent, accuracy: 0.58

# %% [markdown]
# ### Multi-turn

# %%
x_values_pandas_multi_turn = multi_turn_gpt_results["context"] + " " + multi_turn_gpt_results["entity1"] + " " + multi_turn_gpt_results["entity2"]
x_values_multi_turn = x_values_pandas_multi_turn.to_numpy()
y_values_multi_turn = multi_turn_gpt_results["label"].to_numpy()

# create dummy classifier
dummy_clf_uniform = DummyClassifier(strategy='uniform', random_state=42)
dummy_clf_mostfreq = DummyClassifier(strategy='most_frequent', random_state=42)
# train a model
dummy_clf_uniform.fit(x_values_multi_turn, y_values_multi_turn)
dummy_clf_mostfreq.fit(x_values_multi_turn, y_values_multi_turn)
# get accuracy score
print(f"Dummy classifier on single-turn data, strategy uniform, accuracy: {dummy_clf_uniform.score(x_values_multi_turn, y_values_multi_turn)}")
print(f"Dummy classifier on single-turn data, strategy most-frequent, accuracy: {dummy_clf_mostfreq.score(x_values_multi_turn, y_values_multi_turn)}")
# Out:
# Dummy classifier on single-turn data, strategy uniform, accuracy: 0.53
# Dummy classifier on single-turn data, strategy most-frequent, accuracy: 0.51

# %% [markdown]
# # Entity type evaluation
# Evaluate for which entity types the GPT performs best.

# %%
def get_entity_type_cnts(df, prompt_label, entity_cnts, classified_correct):
  if classified_correct: # GPT classified label correct
    correct_items = df[df['label'] == df[prompt_label]]
    print("Corpus items correctly classified by GPT prompt continuations")
  else: # GPT classified label incorrect
    correct_items = df[df['label'] != df[prompt_label]]
    print("Corpus items incorrectly classified by GPT prompt continuations")
  avg_num_attrs = 0
  for idx in range(len(correct_items)):
    avg_num_attrs += ((len(correct_items.iloc[idx]['attrs_entity1']) + len(correct_items.iloc[idx]['attrs_entity2'])) / 2)
    for attr in correct_items.iloc[idx]['attrs_entity1']:
      if attr in entity_cnts:
        entity_cnts[attr] += 1
      else:
        entity_cnts[attr] = 1
    for attr in correct_items.iloc[idx]['attrs_entity2']:
      if attr in entity_cnts:
        entity_cnts[attr] += 1
      else:
        entity_cnts[attr] = 1
  # sort dict by value
  entity_cnts_sorted = {k: v for k, v in sorted(entity_cnts.items(), key=lambda item: item[1], reverse=True)}
  print(f"\t Average number of attributes per corpus item: {avg_num_attrs / len(correct_items)}")
  print(f"\t Number of distinct KB attributes: {len(entity_cnts_sorted.keys())}")
  print(f"\t Total number of occurrences: {sum(entity_cnts_sorted.values())}")
  return entity_cnts_sorted

# %%
def evaluate_categories_for_entity_attributes(datasplit, df, prompt):
  print(f"--- Evaluation for {datasplit} data with {prompt} --- \n")

  # store entity attributes which were correctly classified with GPT prompt
  correctly_classified_entity_attrs = {}
  correctly_classified_entity_attrs_sorted = get_entity_type_cnts(df, prompt, correctly_classified_entity_attrs, classified_correct=True)

  # store entity attributes which were incorrectly classified with GPT prompt
  incorrectly_classified_entity_attrs = {}
  incorrectly_classified_entity_attrs_sorted = get_entity_type_cnts(df, prompt, incorrectly_classified_entity_attrs, classified_correct=False)

  # check which KB attributes were correctly classified and which were not
  print("KB attributes which were only correctly classified:")
  attrs_only_correctly_classified = {k:v for k,v in correctly_classified_entity_attrs_sorted.items() if k not in incorrectly_classified_entity_attrs_sorted}
  attrs_only_correctly_classified_sorted = {k: v for k, v in sorted(attrs_only_correctly_classified.items(), key=lambda item: item[1], reverse=True)}
  print(attrs_only_correctly_classified_sorted)

  print("KB attributes which were only incorrectly classified:")
  attrs_only_incorrectly_classified = {k:v for k,v in incorrectly_classified_entity_attrs_sorted.items() if k not in correctly_classified_entity_attrs_sorted}
  attrs_only_incorrectly_classified_sorted = {k: v for k, v in sorted(attrs_only_incorrectly_classified.items(), key=lambda item: item[1], reverse=True)}
  print(attrs_only_incorrectly_classified_sorted)

  print("Top 10 correctly classified entity attributes:")
  total_num_attrs = sum(correctly_classified_entity_attrs_sorted.values())
  correctly = {k: v / total_num_attrs for k, v in correctly_classified_entity_attrs_sorted.items()}
  print(dict(list(correctly.items())[0: 10]))

  print("Top 10 incorrectly classified entity attributes:")
  total_num_attrs = sum(incorrectly_classified_entity_attrs_sorted.values())
  incorrectly = {k: v / total_num_attrs for k, v in incorrectly_classified_entity_attrs_sorted.items()}
  print(dict(list(incorrectly.items())[0: 10]))
  print('\n')

# %% [markdown]
# ## Single-turn

# %%
evaluate_categories_for_entity_attributes('single-turn', single_turn_gpt_results, 'prompt0_label')
evaluate_categories_for_entity_attributes('single-turn', single_turn_gpt_results, 'prompt1_label')
evaluate_categories_for_entity_attributes('single-turn', single_turn_gpt_results, 'prompt2_label')
# Out:
# --- Evaluation for single-turn data with prompt0_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 5.791666666666667
# 	 Number of distinct KB attributes: 148
# 	 Total number of occurrences: 556
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 5.451923076923077
# 	 Number of distinct KB attributes: 146
# 	 Total number of occurrences: 567
# KB attributes which were only correctly classified:
# {'geography.mountain': 6, 'government.politician': 3, 'medicine.drug': 3, 'book.character': 2, 'tv.character': 2, 'government.u_s_congressperson': 2, 'music.soundtrack': 2, 'tv.crewmember': 2, 'book.subject': 2, 'film.subject': 2, 'education.educational_institution.school_type': 2, 'school"': 2, 'education.school': 2, 'film.director': 2, 'tv.director': 2, 'location.admin_division_2': 2, 'location.us_county': 2, 'medicine.medical_treatment': 2, 'medicine.medical_procedure': 2, 'medicine.drug_formulation_ingredient': 2, 'medicine.condition_prevention_factors': 2, 'chemistry.chemical_substance': 2, 'chemistry.chemical_compound': 2, 'internet.social_network_user': 1, 'music.group': 1, 'film.character': 1, 'fictional_universe.agent': 1, 'theater.character': 1, 'geography.volcano': 1, 'application.software_version': 1, 'theater.play': 1, 'fictional_universe.work_of_fiction': 1, 'computer.processor': 1, 'food.cuisine_enum.bagel': 1, 'local.accommodation': 1, 'local.accommodation.type': 1, '"hotel"': 1, 'location.historical_site': 1, 'transportation.bridge': 1, 'tv.program_creator': 1, 'tv.writer': 1, 'cvg.computer_game_subject': 1, 'media_common.quotation_subject': 1, 'boats.ship_type': 1, 'boats.ship_class': 1, 'book.edition': 1, '"Elementary': 1, '"High': 1, 'music.music_video_director': 1, 'tv.producer': 1, 'book.literary_series': 1, 'film.music_contributor': 1, 'transportation.transportation_structure': 1, 'transportation.trail': 1, 'transportation.routable_structure': 1, 'cvg.computer_game_distribution_system': 1, 'music.record_label': 1, 'internet.author': 1, 'computer.software_developer': 1, 'military.conflict': 1}
# KB attributes which were only incorrectly classified:
# {'award.winning_work': 6, 'music.composition': 4, 'location.populated_place': 2, 'location.city': 2, 'meteorology.tropical_cyclone': 2, 'sports.school_sports_team': 2, 'education.school_district': 2, 'religion.place_of_worship': 2, 'broadcast.media_season': 2, 'tv.series_season': 2, 'award.competition': 2, 'computer.computer': 2, 'boats.ship': 2, 'visual_art.visual_artist': 1, 'comic_books.series': 1, 'chemistry.chemical_element': 1, 'location.admin_division_3': 1, 'celebrities.celebrity': 1, 'fictional_universe.person_in_fiction': 1, 'music.engineer': 1, 'music.guitarist': 1, 'music.producer': 1, 'tv.personality': 1, 'aviation.aircraft_model': 1, 'government.political_district': 1, 'american_football.team': 1, 'finance.financial_institution': 1, 'military.person': 1, 'award.category': 1, 'fictional_universe.organization': 1, 'location.sovereign': 1, 'government.governmental_jurisdiction': 1, 'location.country': 1, 'location.country_region': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'broadcast.am_terrestrial_broadcast_facility': 1, 'broadcast.fm_terrestrial_broadcast_facility': 1, 'religion.place_of_worship.religion': 1, 'christianity': 1, 'sports.tournament_event_competitor': 1, 'boxing.boxer': 1, 'olympics.athlete': 1, 'computer.smartphone': 1, 'computer.mobile_device': 1, 'commerce.inventory_item': 1, 'commerce.electronics_product': 1, 'law.us_patent': 1, 'law.patent': 1, 'event.venue': 1, 'food.cuisine_enum.coffee_and_espresso': 1, 'astronomy.celestial_object': 1, 'astronomy.moon': 1, 'astronomy.orbital_relationship': 1, 'astronomy.star_system_body': 1, 'projects.project_participant': 1, 'law.inventor': 1, 'film.cinematographer': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.10071942446043165, 'media_common.cataloged_instance': 0.08992805755395683, 'media_common.creative_work': 0.050359712230215826, 'event.agent': 0.04136690647482014, 'people.person': 0.03237410071942446, 'location.location': 0.02877697841726619, 'broadcast.content': 0.02697841726618705, 'biology.organism': 0.025179856115107913, 'commerce.product': 0.017985611510791366, 'film.film': 0.017985611510791366}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.1128747795414462, 'media_common.cataloged_instance': 0.10405643738977072, 'media_common.creative_work': 0.06701940035273368, 'event.agent': 0.04409171075837742, 'broadcast.content': 0.03527336860670194, 'people.person': 0.029982363315696647, 'biology.organism': 0.02292768959435626, 'award.nominated_work': 0.02292768959435626, 'location.location': 0.02292768959435626, 'commerce.product': 0.01763668430335097}
#
#
# --- Evaluation for single-turn data with prompt1_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 6.463414634146342
# 	 Number of distinct KB attributes: 126
# 	 Total number of occurrences: 530
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 5.02542372881356
# 	 Number of distinct KB attributes: 153
# 	 Total number of occurrences: 593
# KB attributes which were only correctly classified:
# {'award.winning_work': 6, 'business.employer': 4, '=': 4, 'broadcast.broadcast': 4, 'broadcast.radio_station': 4, 'media_common.adaptation': 4, 'location.administrative_division': 3, 'government.politician': 3, 'education.educational_institution': 3, 'book.character': 2, 'location.populated_place': 2, 'location.city': 2, 'sports.professional_sports_team': 2, 'basketball.team': 2, 'meteorology.tropical_cyclone': 2, 'sports.school_sports_team': 2, 'government.u_s_congressperson': 2, 'education.school_district': 2, 'education.educational_institution.school_type': 2, 'school"': 2, 'education.school': 2, 'film.director': 2, 'tv.director': 2, 'religion.place_of_worship': 2, 'computer.computer': 2, 'location.admin_division_2': 2, 'location.us_county': 2, 'film.character': 1, 'fictional_universe.agent': 1, 'theater.character': 1, 'location.admin_division_3': 1, 'american_football.team': 1, 'finance.financial_institution': 1, 'award.category': 1, 'food.cuisine_enum.bagel': 1, 'local.accommodation': 1, 'local.accommodation.type': 1, '"hotel"': 1, 'location.historical_site': 1, 'transportation.bridge': 1, '"Elementary': 1, '"High': 1, 'music.music_video_director': 1, 'tv.producer': 1, 'broadcast.am_terrestrial_broadcast_facility': 1, 'broadcast.fm_terrestrial_broadcast_facility': 1, 'religion.place_of_worship.religion': 1, 'christianity': 1, 'film.music_contributor': 1, 'computer.smartphone': 1, 'computer.mobile_device': 1, 'commerce.inventory_item': 1, 'commerce.electronics_product': 1}
# KB attributes which were only incorrectly classified:
# {'medicine.drug_brand': 5, 'martial_arts.martial_artist': 4, 'music.composition': 4, 'commerce.brand': 3, 'biology.deceased_organism': 3, 'architecture.venue': 3, 'medicine.drug': 3, 'music.composer': 2, 'music.lyricist': 2, 'law.invention': 2, 'film.story_contributor': 2, 'book.subject': 2, 'film.subject': 2, 'broadcast.media_season': 2, 'tv.series_season': 2, 'award.competition': 2, 'csgaction/action_button': 2, 'medicine.medical_treatment': 2, 'medicine.medical_procedure': 2, 'medicine.drug_formulation_ingredient': 2, 'medicine.condition_prevention_factors': 2, 'chemistry.chemical_substance': 2, 'chemistry.chemical_compound': 2, 'boats.ship': 2, 'internet.social_network_user': 1, 'music.group': 1, 'visual_art.visual_artist': 1, 'comic_books.series': 1, 'chemistry.chemical_element': 1, 'geography.volcano': 1, 'celebrities.celebrity': 1, 'fictional_universe.person_in_fiction': 1, 'music.engineer': 1, 'music.guitarist': 1, 'music.producer': 1, 'tv.personality': 1, 'application.software_version': 1, 'theater.play': 1, 'fictional_universe.work_of_fiction': 1, 'aviation.aircraft_model': 1, 'government.political_district': 1, 'computer.processor': 1, 'military.person': 1, 'fictional_universe.organization': 1, 'location.sovereign': 1, 'government.governmental_jurisdiction': 1, 'location.country': 1, 'location.country_region': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'tv.program_creator': 1, 'tv.writer': 1, 'cvg.computer_game_subject': 1, 'media_common.quotation_subject': 1, 'boats.ship_type': 1, 'boats.ship_class': 1, 'book.edition': 1, 'book.literary_series': 1, 'sports.tournament_event_competitor': 1, 'boxing.boxer': 1, 'olympics.athlete': 1, 'law.us_patent': 1, 'law.patent': 1, 'transportation.transportation_structure': 1, 'transportation.trail': 1, 'transportation.routable_structure': 1, 'event.venue': 1, 'food.cuisine_enum.coffee_and_espresso': 1, 'astronomy.celestial_object': 1, 'astronomy.moon': 1, 'astronomy.orbital_relationship': 1, 'astronomy.star_system_body': 1, 'cvg.computer_game_distribution_system': 1, 'music.record_label': 1, 'projects.project_participant': 1, 'law.inventor': 1, 'film.cinematographer': 1, 'internet.author': 1, 'computer.software_developer': 1, 'military.conflict': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.1, 'media_common.cataloged_instance': 0.09245283018867924, 'media_common.creative_work': 0.052830188679245285, 'event.agent': 0.04716981132075472, 'broadcast.content': 0.035849056603773584, 'location.location': 0.02830188679245283, 'people.person': 0.026415094339622643, 'organization.organization': 0.026415094339622643, 'biology.organism': 0.024528301886792454, 'award.nominated_work': 0.022641509433962263}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.11298482293423272, 'media_common.cataloged_instance': 0.10118043844856661, 'media_common.creative_work': 0.06408094435075885, 'event.agent': 0.0387858347386172, 'people.person': 0.03541315345699832, 'broadcast.content': 0.026981450252951095, 'commerce.product': 0.023608768971332208, 'biology.organism': 0.023608768971332208, 'location.location': 0.023608768971332208, 'commerce.consumer_product': 0.02023608768971332}
#
#
# --- Evaluation for single-turn data with prompt2_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 5.010869565217392
# 	 Number of distinct KB attributes: 124
# 	 Total number of occurrences: 461
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 6.12962962962963
# 	 Number of distinct KB attributes: 149
# 	 Total number of occurrences: 662
# KB attributes which were only correctly classified:
# {'book.book': 7, 'computer.software': 4, 'government.politician': 3, 'local.restaurant': 3, 'architecture.venue': 3, 'medicine.drug': 3, 'tv.character': 2, 'government.u_s_congressperson': 2, 'music.soundtrack': 2, 'broadcast.media_season': 2, 'tv.series_season': 2, 'award.competition': 2, 'computer.computer': 2, 'csgaction/action_button': 2, 'medicine.medical_treatment': 2, 'medicine.medical_procedure': 2, 'medicine.drug_formulation_ingredient': 2, 'medicine.condition_prevention_factors': 2, 'chemistry.chemical_substance': 2, 'chemistry.chemical_compound': 2, 'boats.ship': 2, 'chemistry.chemical_element': 1, 'application.software_version': 1, 'theater.play': 1, 'fictional_universe.work_of_fiction': 1, 'aviation.aircraft_model': 1, 'government.political_district': 1, 'computer.processor': 1, 'food.cuisine_enum.bagel': 1, 'local.accommodation': 1, 'local.accommodation.type': 1, '"hotel"': 1, 'location.historical_site': 1, 'transportation.bridge': 1, 'location.sovereign': 1, 'government.governmental_jurisdiction': 1, 'location.country': 1, 'location.country_region': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'boats.ship_type': 1, 'boats.ship_class': 1, 'book.edition': 1, 'sports.tournament_event_competitor': 1, 'boxing.boxer': 1, 'olympics.athlete': 1, 'computer.smartphone': 1, 'computer.mobile_device': 1, 'commerce.inventory_item': 1, 'commerce.electronics_product': 1, 'law.us_patent': 1, 'law.patent': 1, 'event.venue': 1, 'food.cuisine_enum.coffee_and_espresso': 1, 'cvg.computer_game_distribution_system': 1, 'music.record_label': 1, 'military.conflict': 1}
# KB attributes which were only incorrectly classified:
# {'film.producer': 6, 'geography.island': 5, 'music.artist': 4, 'american_football.player': 4, 'film.writer': 4, 'business.employer': 4, 'music.composition': 4, 'broadcast.broadcast': 4, 'broadcast.radio_station': 4, 'media_common.adaptation': 4, 'location.administrative_division': 3, 'biology.deceased_organism': 3, 'music.musician': 3, 'education.educational_institution': 3, 'book.character': 2, 'organization.founder': 2, 'location.populated_place': 2, 'location.city': 2, 'sports.professional_sports_team': 2, 'basketball.team': 2, 'meteorology.tropical_cyclone': 2, 'music.composer': 2, 'music.lyricist': 2, 'sports.school_sports_team': 2, 'education.school_district': 2, 'tv.crewmember': 2, 'film.story_contributor': 2, 'symbols.namesake': 2, 'education.educational_institution.school_type': 2, 'school"': 2, 'education.school': 2, 'film.director': 2, 'tv.director': 2, 'religion.place_of_worship': 2, 'location.admin_division_2': 2, 'location.us_county': 2, 'internet.social_network_user': 1, 'music.group': 1, 'visual_art.visual_artist': 1, 'comic_books.series': 1, 'film.character': 1, 'fictional_universe.agent': 1, 'theater.character': 1, 'geography.volcano': 1, 'location.admin_division_3': 1, 'celebrities.celebrity': 1, 'fictional_universe.person_in_fiction': 1, 'music.engineer': 1, 'music.guitarist': 1, 'music.producer': 1, 'tv.personality': 1, 'american_football.team': 1, 'finance.financial_institution': 1, 'military.person': 1, 'award.category': 1, 'fictional_universe.organization': 1, 'tv.program_creator': 1, 'tv.writer': 1, 'cvg.computer_game_subject': 1, 'media_common.quotation_subject': 1, '"Elementary': 1, '"High': 1, 'music.music_video_director': 1, 'tv.producer': 1, 'broadcast.am_terrestrial_broadcast_facility': 1, 'broadcast.fm_terrestrial_broadcast_facility': 1, 'religion.place_of_worship.religion': 1, 'christianity': 1, 'book.literary_series': 1, 'film.music_contributor': 1, 'transportation.transportation_structure': 1, 'transportation.trail': 1, 'transportation.routable_structure': 1, 'astronomy.celestial_object': 1, 'astronomy.moon': 1, 'astronomy.orbital_relationship': 1, 'astronomy.star_system_body': 1, 'projects.project_participant': 1, 'law.inventor': 1, 'film.cinematographer': 1, 'internet.author': 1, 'computer.software_developer': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.12147505422993492, 'media_common.cataloged_instance': 0.10629067245119306, 'media_common.creative_work': 0.07592190889370933, 'broadcast.content': 0.0368763557483731, 'event.agent': 0.03036876355748373, 'commerce.product': 0.03036876355748373, 'commerce.consumer_product': 0.026030368763557483, 'location.location': 0.02386117136659436, 'people.person': 0.021691973969631236, 'film.film': 0.019522776572668113}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.09667673716012085, 'media_common.cataloged_instance': 0.09063444108761329, 'event.agent': 0.0513595166163142, 'media_common.creative_work': 0.04682779456193353, 'people.person': 0.0377643504531722, 'biology.organism': 0.028700906344410877, 'location.location': 0.027190332326283987, 'broadcast.content': 0.027190332326283987, 'organization.organization': 0.021148036253776436, 'award.competitor': 0.019637462235649546}

# %% [markdown]
# ## Multi-turn

# %%
evaluate_categories_for_entity_attributes('multi-turn', multi_turn_gpt_results, 'prompt0_label')
evaluate_categories_for_entity_attributes('multi-turn', multi_turn_gpt_results, 'prompt1_label')
evaluate_categories_for_entity_attributes('multi-turn', multi_turn_gpt_results, 'prompt2_label')
evaluate_categories_for_entity_attributes('multi-turn', multi_turn_gpt_results, 'prompt3_label')
# Out:
# --- Evaluation for multi-turn data with prompt0_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 8.633928571428571
# 	 Number of distinct KB attributes: 165
# 	 Total number of occurrences: 967
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 10.022727272727273
# 	 Number of distinct KB attributes: 76
# 	 Total number of occurrences: 882
# KB attributes which were only correctly classified:
# {'astronomy.celestial_object': 10, 'astronomy.orbital_relationship': 10, 'conferences.conference_subject': 6, 'business.employer': 5, 'business.operation': 5, 'organization.organization': 5, 'astronomy.celestial_object_with_coordinate_system': 5, 'astronomy.star': 5, 'astronomy.star_system_body': 5, 'astronomy.asteroid': 5, 'astronomy.astronomical_discovery': 5, 'tv.program': 5, 'cvg.developer': 4, 'computer.software_developer': 4, 'cvg.publisher': 4, 'games.publisher': 4, 'music.singer': 4, 'exhibitions.subject': 3, 'education.field_of_study': 3, 'music.record_label': 3, 'games.game': 3, 'cvg.computer_videogame': 3, 'computer.software': 3, 'food.diet_follower': 3, 'tv.producer': 3, 'common.group': 2, 'tv.series_episode': 2, 'award.discipline': 2, 'computer.software_genre': 2, 'comic_books.genre': 2, 'business.industry': 2, 'tv.subject': 2, 'tv.series_season': 2, 'tv.genre': 2, 'organization.sector': 2, 'media_common.media_genre': 2, 'media_common.catalog_category': 2, 'internet.website_category': 2, 'film.genre': 2, 'film.festival_focus': 2, 'cvg.genre': 2, 'business.issuer': 2, 'time.recurring_event': 2, 'award.recurring_competition': 2, 'geography.river': 1, 'location.country': 1, 'location.country_region': 1, 'location.dated_location': 1, 'location.political_unit': 1, 'location.sovereign': 1, 'meteorology.cyclone_affected_area': 1, 'military.combatant': 1, 'military.unit_place_of_origin': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'organization.scope': 1, 'royalty.kingdom': 1, 'sports.country': 1, 'sports.team_location': 1, 'statistics.economic_group': 1, 'statistics.education_group': 1, 'statistics.environment_group': 1, 'statistics.government_group': 1, 'statistics.health_group': 1, 'statistics.housing_group': 1, 'statistics.infrastructure_group': 1, 'statistics.military_group': 1, 'statistics.population_group': 1, 'symbols.flag_referent': 1, 'travel.destination': 1, 'tv.location': 1, 'food.beer_country_region': 1, 'government.governmental_jurisdiction': 1, 'fictional_universe.setting': 1, 'biology.breed_origin': 1, 'business.asset_owner': 1, 'cvg.computer_game_region': 1, 'distilled_spirits.spirit_producing_region': 1, 'broadcast.genre': 1, 'book.periodical_subject': 1, 'book.magazine_genre': 1, 'book.literary_genre': 1, 'award.hall_of_fame_discipline': 1, 'broadcast.radio_format': 1, 'medicine.risk_factor': 1, 'cvg.designer': 1, 'award.competition': 1, 'broadcast.media_season': 1, 'time.event': 1, 'people.competency': 1, 'visual_art.visual_art_genre': 1, 'people.professional_field': 1, 'music.music_video_genre': 1, 'interests.interest': 1, 'interests.hobby': 1, 'film.format': 1, 'common.text': 1, 'tv.program_creator': 1, 'tv.director': 1, 'visual_art.visual_artist': 1}
# KB attributes which were only incorrectly classified:
# {'automotive.trim_level': 16, 'music.album': 10, 'theater.theatrical_lyricist': 3, 'theater.theatrical_composer': 3, 'music.drummer': 2, 'geography.lake': 2, 'film.story_contributor': 2, 'theater.musical_director': 1, 'education.educational_institution': 1, 'event.performer': 1, 'education.academic': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.0796277145811789, 'media_common.cataloged_instance': 0.07652533609100311, 'event.agent': 0.04343329886246122, 'media_common.creative_work': 0.03619441571871768, 'biology.organism': 0.03205791106514995, 'people.person': 0.02998965873836608, 'music.artist': 0.020682523267838676, 'film.film': 0.01964839710444674, 'broadcast.content': 0.016546018614270942, 'music.composer': 0.016546018614270942}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.08276643990929705, 'media_common.cataloged_instance': 0.07256235827664399, 'event.agent': 0.049886621315192746, 'biology.organism': 0.03968253968253968, 'music.artist': 0.03741496598639456, 'commerce.consumer_product': 0.031746031746031744, 'award.competitor': 0.030612244897959183, 'award.nominee': 0.030612244897959183, 'tv.actor': 0.02947845804988662, 'people.person': 0.02947845804988662}
#
#
# --- Evaluation for multi-turn data with prompt1_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 9.711538461538462
# 	 Number of distinct KB attributes: 77
# 	 Total number of occurrences: 1010
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 8.739583333333334
# 	 Number of distinct KB attributes: 164
# 	 Total number of occurrences: 839
# KB attributes which were only correctly classified:
# {'automotive.trim_level': 16, 'cvg.computer_game_subject': 11, 'music.album': 10, 'theater.theatrical_lyricist': 3, 'theater.theatrical_composer': 3, 'music.drummer': 2, 'geography.lake': 2, 'film.story_contributor': 2, 'theater.musical_director': 1, 'education.educational_institution': 1, 'event.performer': 1, 'education.academic': 1}
# KB attributes which were only incorrectly classified:
# {'astronomy.celestial_object': 10, 'astronomy.orbital_relationship': 10, 'conferences.conference_subject': 6, 'business.employer': 5, 'business.operation': 5, 'organization.organization': 5, 'astronomy.celestial_object_with_coordinate_system': 5, 'astronomy.star': 5, 'astronomy.star_system_body': 5, 'astronomy.asteroid': 5, 'astronomy.astronomical_discovery': 5, 'tv.program': 5, 'cvg.developer': 4, 'computer.software_developer': 4, 'cvg.publisher': 4, 'games.publisher': 4, 'music.singer': 4, 'exhibitions.subject': 3, 'education.field_of_study': 3, 'games.game': 3, 'cvg.computer_videogame': 3, 'computer.software': 3, 'food.diet_follower': 3, 'tv.producer': 3, 'common.group': 2, 'tv.series_episode': 2, 'award.discipline': 2, 'computer.software_genre': 2, 'comic_books.genre': 2, 'business.industry': 2, 'tv.subject': 2, 'tv.series_season': 2, 'tv.genre': 2, 'organization.sector': 2, 'media_common.media_genre': 2, 'media_common.catalog_category': 2, 'internet.website_category': 2, 'film.genre': 2, 'film.festival_focus': 2, 'cvg.genre': 2, 'business.issuer': 2, 'time.recurring_event': 2, 'award.recurring_competition': 2, 'geography.river': 1, 'location.country': 1, 'location.country_region': 1, 'location.dated_location': 1, 'location.political_unit': 1, 'location.sovereign': 1, 'meteorology.cyclone_affected_area': 1, 'military.combatant': 1, 'military.unit_place_of_origin': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'organization.scope': 1, 'royalty.kingdom': 1, 'sports.country': 1, 'sports.team_location': 1, 'statistics.economic_group': 1, 'statistics.education_group': 1, 'statistics.environment_group': 1, 'statistics.government_group': 1, 'statistics.health_group': 1, 'statistics.housing_group': 1, 'statistics.infrastructure_group': 1, 'statistics.military_group': 1, 'statistics.population_group': 1, 'symbols.flag_referent': 1, 'travel.destination': 1, 'tv.location': 1, 'food.beer_country_region': 1, 'government.governmental_jurisdiction': 1, 'fictional_universe.setting': 1, 'biology.breed_origin': 1, 'business.asset_owner': 1, 'cvg.computer_game_region': 1, 'distilled_spirits.spirit_producing_region': 1, 'broadcast.genre': 1, 'book.periodical_subject': 1, 'book.magazine_genre': 1, 'book.literary_genre': 1, 'award.hall_of_fame_discipline': 1, 'broadcast.radio_format': 1, 'medicine.risk_factor': 1, 'cvg.designer': 1, 'award.competition': 1, 'broadcast.media_season': 1, 'time.event': 1, 'people.competency': 1, 'visual_art.visual_art_genre': 1, 'people.professional_field': 1, 'music.music_video_genre': 1, 'interests.interest': 1, 'interests.hobby': 1, 'film.format': 1, 'common.text': 1, 'tv.program_creator': 1, 'tv.director': 1, 'visual_art.visual_artist': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.08415841584158416, 'media_common.cataloged_instance': 0.07722772277227723, 'event.agent': 0.04950495049504951, 'biology.organism': 0.039603960396039604, 'music.artist': 0.03663366336633663, 'people.person': 0.0297029702970297, 'award.competitor': 0.0297029702970297, 'award.nominee': 0.0297029702970297, 'commerce.consumer_product': 0.0297029702970297, 'tv.actor': 0.027722772277227723}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.07747318235995232, 'media_common.cataloged_instance': 0.07151370679380215, 'event.agent': 0.04290822407628129, 'media_common.creative_work': 0.03456495828367104, 'biology.organism': 0.03098927294398093, 'people.person': 0.029797377830750895, 'film.film': 0.02026221692491061, 'music.artist': 0.01907032181168057, 'broadcast.content': 0.017878426698450536, 'music.composer': 0.0166865315852205}
#
#
# --- Evaluation for multi-turn data with prompt2_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 9.806122448979592
# 	 Number of distinct KB attributes: 127
# 	 Total number of occurrences: 961
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 8.705882352941176
# 	 Number of distinct KB attributes: 125
# 	 Total number of occurrences: 888
# KB attributes which were only correctly classified:
# {'cvg.computer_game_subject': 11, 'business.employer': 5, 'business.operation': 5, 'organization.organization': 5, 'cvg.developer': 4, 'computer.software_developer': 4, 'cvg.publisher': 4, 'games.publisher': 4, 'fictional_universe.person_in_fiction': 3, 'games.game': 3, 'cvg.computer_videogame': 3, 'computer.software': 3, 'common.group': 2, 'business.issuer': 2, 'film.story_contributor': 2, 'geography.river': 1, 'location.country': 1, 'location.country_region': 1, 'location.dated_location': 1, 'location.political_unit': 1, 'location.sovereign': 1, 'meteorology.cyclone_affected_area': 1, 'military.combatant': 1, 'military.unit_place_of_origin': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'organization.scope': 1, 'royalty.kingdom': 1, 'sports.country': 1, 'sports.team_location': 1, 'statistics.economic_group': 1, 'statistics.education_group': 1, 'statistics.environment_group': 1, 'statistics.government_group': 1, 'statistics.health_group': 1, 'statistics.housing_group': 1, 'statistics.infrastructure_group': 1, 'statistics.military_group': 1, 'statistics.population_group': 1, 'symbols.flag_referent': 1, 'travel.destination': 1, 'tv.location': 1, 'food.beer_country_region': 1, 'government.governmental_jurisdiction': 1, 'fictional_universe.setting': 1, 'biology.breed_origin': 1, 'business.asset_owner': 1, 'cvg.computer_game_region': 1, 'distilled_spirits.spirit_producing_region': 1, 'cvg.designer': 1, 'education.academic': 1}
# KB attributes which were only incorrectly classified:
# {'music.album': 10, 'tv.program': 5, 'education.field_of_study': 3, 'food.diet_follower': 3, 'tv.producer': 3, 'book.translated_work': 3, 'tv.series_episode': 2, 'award.discipline': 2, 'computer.software_genre': 2, 'comic_books.genre': 2, 'business.industry': 2, 'tv.series_season': 2, 'tv.genre': 2, 'organization.sector': 2, 'media_common.media_genre': 2, 'media_common.catalog_category': 2, 'internet.website_category': 2, 'film.genre': 2, 'film.festival_focus': 2, 'cvg.genre': 2, 'business.board_member': 2, 'music.music_video_performer': 2, 'geography.lake': 2, 'time.recurring_event': 2, 'award.recurring_competition': 2, 'theater.musical_director': 1, 'education.educational_institution': 1, 'broadcast.genre': 1, 'book.periodical_subject': 1, 'book.magazine_genre': 1, 'book.literary_genre': 1, 'award.hall_of_fame_discipline': 1, 'broadcast.radio_format': 1, 'medicine.risk_factor': 1, 'award.competition': 1, 'broadcast.media_season': 1, 'time.event': 1, 'people.competency': 1, 'visual_art.visual_art_genre': 1, 'people.professional_field': 1, 'music.music_video_genre': 1, 'interests.interest': 1, 'interests.hobby': 1, 'film.format': 1, 'common.text': 1, 'tv.program_creator': 1, 'tv.director': 1, 'visual_art.visual_artist': 1, 'event.performer': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.07700312174817898, 'media_common.cataloged_instance': 0.06555671175858481, 'event.agent': 0.05827263267429761, 'biology.organism': 0.04162330905306972, 'music.artist': 0.03225806451612903, 'people.person': 0.031217481789802288, 'award.competitor': 0.027055150884495317, 'award.nominee': 0.027055150884495317, 'internet.social_network_user': 0.023933402705515087, 'tv.actor': 0.023933402705515087}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.08558558558558559, 'media_common.cataloged_instance': 0.08445945945945946, 'media_common.creative_work': 0.04279279279279279, 'event.agent': 0.033783783783783786, 'biology.organism': 0.02927927927927928, 'commerce.consumer_product': 0.02927927927927928, 'people.person': 0.028153153153153154, 'music.artist': 0.024774774774774775, 'music.composer': 0.02252252252252252, 'commerce.product': 0.021396396396396396}
#
#
# --- Evaluation for multi-turn data with prompt3_label ---
#
# Corpus items correctly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 10.23404255319149
# 	 Number of distinct KB attributes: 149
# 	 Total number of occurrences: 962
# Corpus items incorrectly classified by GPT prompt continuations
# 	 Average number of attributes per corpus item: 8.367924528301886
# 	 Number of distinct KB attributes: 126
# 	 Total number of occurrences: 887
# KB attributes which were only correctly classified:
# {'tv.program': 5, 'games.game': 3, 'cvg.computer_videogame': 3, 'computer.software': 3, 'time.recurring_event': 2, 'award.recurring_competition': 2, 'geography.river': 1, 'location.country': 1, 'location.country_region': 1, 'location.dated_location': 1, 'location.political_unit': 1, 'location.sovereign': 1, 'meteorology.cyclone_affected_area': 1, 'military.combatant': 1, 'military.unit_place_of_origin': 1, 'olympics.participating_country': 1, 'organization.member': 1, 'organization.scope': 1, 'royalty.kingdom': 1, 'sports.country': 1, 'sports.team_location': 1, 'statistics.economic_group': 1, 'statistics.education_group': 1, 'statistics.environment_group': 1, 'statistics.government_group': 1, 'statistics.health_group': 1, 'statistics.housing_group': 1, 'statistics.infrastructure_group': 1, 'statistics.military_group': 1, 'statistics.population_group': 1, 'symbols.flag_referent': 1, 'travel.destination': 1, 'tv.location': 1, 'food.beer_country_region': 1, 'government.governmental_jurisdiction': 1, 'fictional_universe.setting': 1, 'biology.breed_origin': 1, 'business.asset_owner': 1, 'cvg.computer_game_region': 1, 'distilled_spirits.spirit_producing_region': 1, 'award.competition': 1, 'broadcast.media_season': 1, 'time.event': 1, 'people.competency': 1, 'visual_art.visual_art_genre': 1, 'people.professional_field': 1, 'music.music_video_genre': 1, 'interests.interest': 1, 'interests.hobby': 1, 'film.format': 1}
# KB attributes which were only incorrectly classified:
# {'automotive.trim_level': 16, 'music.album': 10, 'biology.organism_classification': 10, 'music.singer': 4, 'tv.producer': 3, 'book.translated_work': 3, 'tv.subject': 2, 'business.issuer': 2, 'business.board_member': 2, 'music.music_video_performer': 2, 'geography.lake': 2, 'theater.musical_director': 1, 'education.educational_institution': 1, 'broadcast.genre': 1, 'book.periodical_subject': 1, 'book.magazine_genre': 1, 'book.literary_genre': 1, 'award.hall_of_fame_discipline': 1, 'broadcast.radio_format': 1, 'medicine.risk_factor': 1, 'cvg.designer': 1, 'common.text': 1, 'tv.program_creator': 1, 'tv.director': 1, 'visual_art.visual_artist': 1, 'event.performer': 1, 'education.academic': 1}
# Top 10 correctly classified entity attributes:
# {'ratings.rated_entity': 0.08108108108108109, 'media_common.cataloged_instance': 0.07484407484407485, 'event.agent': 0.0498960498960499, 'biology.organism': 0.036382536382536385, 'music.artist': 0.033264033264033266, 'media_common.creative_work': 0.02702702702702703, 'people.person': 0.02598752598752599, 'award.competitor': 0.02390852390852391, 'award.nominee': 0.02390852390852391, 'broadcast.artist': 0.02390852390852391}
# Top 10 incorrectly classified entity attributes:
# {'ratings.rated_entity': 0.08117249154453213, 'media_common.cataloged_instance': 0.07440811724915446, 'event.agent': 0.04284103720405862, 'biology.organism': 0.03494926719278467, 'people.person': 0.033821871476888386, 'commerce.consumer_product': 0.03156708004509583, 'media_common.creative_work': 0.030439684329199548, 'music.artist': 0.02367531003382187, 'tv.actor': 0.020293122886133032, 'automotive.automotive_class': 0.020293122886133032}
